# %% [markdown]
# # batch size

# %%
from rac.experiment_data import ExperimentReader
er = ExperimentReader(metrics=["rand"])

start_index = 1

config = {
    "_experiment_name": "ablation1",
    "_num_repeats": 14,
    "_n_workers": 14,
    "_local": True,
    "_verbose": True,
    "_overwrite": True,
    "_mode": "ac",

    "seed": 14,
    "batch_size": [100],
    "noise_level": [0.4],
    "clustering_alg": "CC",
    "warm_start": [0.01],
    "K_init": 10,
    "sim_init": [0.01],
    "sim_init_type": ["zeros"],
    "sample_size": 1,
    "infer_threshold": [-1],
    "start_inferring": [0],

    "acq_fn": ["info_gain_object", "info_gain_pairs"],

    "eps": [0.8],
    "beta": [1],
    "tau": [3],
    "num_maxmin_edges": -1,

    "alpha1": [1],
    "alpha2": [0.5],
    "alpha3": [1],

    "r": [0.02],
    "num_mc_samples": [5],
    "num_mc": [50],

    "num_mc_mf": [1],
    "mf_noise": [0],
    "reinit": [False],
    "mf_iterations": [200],
    "conv_threshold": [1e-8],

    "mf_acq_noise": [False],
    "acq_noise": [True],
    "use_power": True,
    "power_beta": [2],
    "sparse_sim_matrix": True,
    "mean_field_beta": [3],
    "info_gain_lambda": 1,
    "num_edges_info_gain": [20],
    "info_gain_pair_mode": ["entropy"],

    "dataset_name": "synthetic",
    "dataset_n_samples": 500,
    "dataset_n_clusters": [10],
    "dataset_class_balance": None,
    "dataset_class_sep": [1.5],
    "dataset_n_features": [10],
    "dataset_y_flip": [0],
}

start_index = er.generate_experiments(
    folder="../configs/ablation_slow",
    options_to_keep=[],
    start_index=start_index, 
    **config
)

# %%
from rac.experiment_data import ExperimentReader
er = ExperimentReader(metrics=["rand"])
data = er.read_all_data(folder="../experiment_results_local/ablation1")


config = {
    "_experiment_name": "ablation1",
    "_num_repeats": 14,
    "_n_workers": 14,
    "_local": True,
    "_verbose": True,
    "_overwrite": False,
    "_mode": "ac",

    "seed": 14,
    "batch_size": [100, 500, 1000, 2000],
    "noise_level": [0.4],
    "clustering_alg": "CC",
    "warm_start": [0.01],
    "K_init": 10,
    "sim_init": [0.01],
    "sim_init_type": ["zeros"],
    "sample_size": 1,
    "infer_threshold": [-1],
    "start_inferring": [0],

    "acq_fn": ["unif", "maxmin", "maxexp", "entropy", "info_gain_pairs_random", "info_gain_object", "info_gain_pairs"],

    "eps": [0.8],
    "beta": [1],
    "tau": [3],
    "num_maxmin_edges": -1,

    "alpha1": [1],
    "alpha2": [0.5],
    "alpha3": [1],

    "r": [0.02],
    "num_mc_samples": [5],
    "num_mc": [50],

    "num_mc_mf": [1],
    "mf_noise": [0],
    "reinit": [False],
    "mf_iterations": [200],
    "conv_threshold": [1e-8],

    "mf_acq_noise": [False],
    "acq_noise": [True],
    "use_power": True,
    "power_beta": [2],
    "sparse_sim_matrix": True,
    "mean_field_beta": [3],
    "info_gain_lambda": 1,
    "num_edges_info_gain": [20],
    "info_gain_pair_mode": ["entropy"],

    "dataset_name": "synthetic",
    "dataset_n_samples": 500,
    "dataset_n_clusters": [10],
    "dataset_class_balance": None,
    "dataset_class_sep": [1.5],
    "dataset_n_features": [10],
    "dataset_y_flip": [0],
}

er.generate_AL_curves3(
    data,
    save_location="../plots/batch_size/",
    categorize=[],
    compare=["acq_fn"],
    vary=["batch_size"],
    options_in_file_name=["num_edges_info_gain"],
    auc=True,
    summary_method="batch_size",
    indices=[], 
    threshold=1,
    err_style="bars",
    marker="o",
    markersize=6,
    capsize=6,
    linestyle="solid",
    prop=False,
    **config
)

# %% [markdown]
# # noise level

# %%
config = {
    "_experiment_name": "ablation2",
    "_num_repeats": 14,
    "_n_workers": 14,
    "_local": True,
    "_verbose": True,
    "_overwrite": True,
    "_mode": "ac",

    "seed": 14,
    "batch_size": [0.0025],
    "noise_level": [0.8],
    "clustering_alg": "CC",
    "warm_start": [0.01],
    "K_init": 10,
    "sim_init": [0.01],
    "sim_init_type": ["zeros"],
    "sample_size": 1,
    "infer_threshold": [-1],
    "start_inferring": [0],

    "acq_fn": ["info_gain_pairs"],

    "eps": [0.8],
    "beta": [1],
    "tau": [3],
    "num_maxmin_edges": -1,

    "alpha1": [1],
    "alpha2": [0.5],
    "alpha3": [1],

    "r": [0.02],
    "num_mc_samples": [5],
    "num_mc": [50],

    "num_mc_mf": [1],
    "mf_noise": [0],
    "reinit": [False],
    "mf_iterations": [200],
    "conv_threshold": [1e-8],

    "mf_acq_noise": [False],
    "acq_noise": [True],
    "use_power": True,
    "power_beta": [2],
    "sparse_sim_matrix": True,
    "mean_field_beta": [3],
    "info_gain_lambda": 1,
    "num_edges_info_gain": [10],
    "info_gain_pair_mode": ["entropy"],

    "dataset_name": "synthetic",
    "dataset_n_samples": 500,
    "dataset_n_clusters": [10],
    "dataset_class_balance": None,
    "dataset_class_sep": [1.5],
    "dataset_n_features": [10],
    "dataset_y_flip": [0],
}

start_index = er.generate_experiments(
    folder="../configs/ablation_slow",
    options_to_keep=[],
    start_index=start_index, 
    **config
)

# %%
from rac.experiment_data import ExperimentReader
er = ExperimentReader(metrics=["rand"])
data = er.read_all_data(folder="../experiment_results_local/ablation2")


config = {
    "_experiment_name": "ablation2",
    "_num_repeats": 14,
    "_n_workers": 14,
    "_local": True,
    "_verbose": True,
    "_overwrite": False,
    "_mode": "ac",

    "seed": 14,
    "batch_size": [0.0025],
    "noise_level": [0.0, 0.2, 0.4, 0.6, 0.8],
    "clustering_alg": "CC",
    "warm_start": [0.01],
    "K_init": 10,
    "sim_init": [0.01],
    "sim_init_type": ["zeros"],
    "sample_size": 1,
    "infer_threshold": [-1],
    "start_inferring": [0],

    "acq_fn": ["unif", "maxmin", "maxexp", "entropy", "info_gain_pairs_random", "info_gain_object", "info_gain_pairs"],

    "eps": [0.8],
    "beta": [1],
    "tau": [3],
    "num_maxmin_edges": -1,

    "alpha1": [1],
    "alpha2": [0.5],
    "alpha3": [1],

    "r": [0.02],
    "num_mc_samples": [5],
    "num_mc": [50],

    "num_mc_mf": [1],
    "mf_noise": [0],
    "reinit": [False],
    "mf_iterations": [200],
    "conv_threshold": [1e-8],

    "mf_acq_noise": [False],
    "acq_noise": [True],
    "use_power": True,
    "power_beta": [2],
    "sparse_sim_matrix": True,
    "mean_field_beta": [3],
    "info_gain_lambda": 1,
    "num_edges_info_gain": [10],
    "info_gain_pair_mode": ["entropy"],

    "dataset_name": "synthetic",
    "dataset_n_samples": 500,
    "dataset_n_clusters": [10],
    "dataset_class_balance": None,
    "dataset_class_sep": [1.5],
    "dataset_n_features": [10],
    "dataset_y_flip": [0],
}

er.generate_AL_curves3(
    data,
    save_location="../plots/noise_level2/",
    categorize=[],
    compare=["acq_fn"],
    vary=["noise_level"],
    options_in_file_name=[],
    auc=True,
    summary_method="auc_max_ind",
    indices=[], 
    threshold=1,
    err_style="bars",
    marker="o",
    markersize=6,
    capsize=6,
    linestyle="solid",
    prop=False,
    **config
)

# %% [markdown]
# # runtime

# %%
config = {
    "_experiment_name": "ablation3",
    "_num_repeats": 14,
    "_n_workers": 14,
    "_local": True,
    "_verbose": True,
    "_overwrite": False,
    "_mode": "ac",

    "seed": 14,
    "batch_size": [0.0025],
    "noise_level": [0.4],
    "clustering_alg": "CC",
    "warm_start": [0.01],
    "K_init": 10,
    "sim_init": [0.01],
    "sim_init_type": ["zeros"],
    "sample_size": 1,
    "infer_threshold": [-1],
    "start_inferring": [0],

    "acq_fn": ["unif", "maxmin", "maxexp", "entropy", "info_gain_pairs_random", "info_gain_object", "info_gain_pairs"],

    "eps": [0.8],
    "beta": [1],
    "tau": [3],
    "num_maxmin_edges": -1,

    "alpha1": [1],
    "alpha2": [0.5],
    "alpha3": [1],

    "r": [0.02],
    "num_mc_samples": [5],
    "num_mc": [50],

    "num_mc_mf": [1],
    "mf_noise": [0],
    "reinit": [False],
    "mf_iterations": [200],
    "conv_threshold": [1e-8],

    "mf_acq_noise": [False],
    "acq_noise": [True],
    "use_power": True,
    "power_beta": [2],
    "sparse_sim_matrix": True,
    "mean_field_beta": [3],
    "info_gain_lambda": 1,
    "num_edges_info_gain": [10],
    "info_gain_pair_mode": ["entropy"],

    "dataset_name": "synthetic",
    "dataset_n_samples": 500,
    "dataset_n_clusters": [10],
    "dataset_class_balance": None,
    "dataset_class_sep": [1.5],
    "dataset_n_features": [10],
    "dataset_y_flip": [0],
}

start_index = er.generate_experiments(
    folder="../configs/ablation",
    options_to_keep=[],
    start_index=start_index, 
    **config
)

# %%
from rac.experiment_data import ExperimentReader
er = ExperimentReader(metrics=["rand", "num_repeat_queries", "num_violations", "time_select_batch"])
data = er.read_all_data(folder="../experiment_results_local/ablation3")

config = {
    "_experiment_name": "ablation3",
    "_num_repeats": 14,
    "_n_workers": 14,
    "_local": True,
    "_verbose": True,
    "_overwrite": False,
    "_mode": "ac",

    "seed": 14,
    "batch_size": [0.0025],
    "noise_level": [0.4],
    "clustering_alg": "CC",
    "warm_start": [0.01],
    "K_init": 10,
    "sim_init": [0.01],
    "sim_init_type": ["zeros"],
    "sample_size": 1,
    "infer_threshold": [-1],
    "start_inferring": [0],

    "acq_fn": ["unif", "maxmin", "maxexp", "entropy", "info_gain_pairs_random", "info_gain_object", "info_gain_pairs"],

    "eps": [0.8],
    "beta": [1],
    "tau": [3],
    "num_maxmin_edges": -1,

    "alpha1": [1],
    "alpha2": [0.5],
    "alpha3": [1],

    "r": [0.02],
    "num_mc_samples": [5],
    "num_mc": [50],

    "num_mc_mf": [1],
    "mf_noise": [0],
    "reinit": [False],
    "mf_iterations": [200],
    "conv_threshold": [1e-8],

    "mf_acq_noise": [False],
    "acq_noise": [True],
    "use_power": True,
    "power_beta": [2],
    "sparse_sim_matrix": True,
    "mean_field_beta": [3],
    "info_gain_lambda": 1,
    "num_edges_info_gain": [10],
    "info_gain_pair_mode": ["entropy"],

    "dataset_name": "synthetic",
    "dataset_n_samples": 500,
    "dataset_n_clusters": [10],
    "dataset_class_balance": None,
    "dataset_class_sep": [1.5],
    "dataset_n_features": [10],
    "dataset_y_flip": [0],
}

er.generate_AL_curves2(
    data,
    save_location="../plots/time/",
    categorize=[],
    compare=["acq_fn"],
    vary=["x"],
    options_in_file_name=[],
    auc=True,
    summary_method="auc_max_ind",
    indices=[], 
    threshold=1,
    err_style="band",
    marker="o",
    markersize=6,
    capsize=6,
    linestyle="solid",
    prop=False,
    varian=0.5,
    **config
)
# Out:
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:802: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:802: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:802: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:802: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)

# %% [markdown]
# # requery

# %%
from rac.experiment_data import ExperimentReader
er = ExperimentReader(metrics=["rand", "num_repeat_queries", "num_violations", "time_select_batch"])
start_index = 1
config = {
    "_experiment_name": "ablation_req_new",
    "_num_repeats": 14,
    "_n_workers": 14,
    "_local": True,
    "_verbose": True,
    "_overwrite": False,
    "_mode": "ac",

    "seed": 14,
    "batch_size": [0.0025],
    "noise_level": [0.6, 0.7],
    "clustering_alg": "CC",
    "warm_start": [0.01],
    "K_init": 10,
    "sim_init": [0.01],
    "sim_init_type": ["zeros"],
    "sample_size": 1,
    "infer_threshold": [-1],
    "start_inferring": [0],

    "acq_fn": ["unif", "maxmin", "maxexp", "entropy", "info_gain_pairs_random", "info_gain_object"],

    "eps": [0.3, 0.8],
    "beta": [1],
    "tau": [1, 2, 3, 5, 10, 500],
    "num_maxmin_edges": -1,

    "alpha1": [1],
    "alpha2": [0.5],
    "alpha3": [1],

    "r": [0.02],
    "num_mc_samples": [5],
    "num_mc": [50],

    "num_mc_mf": [1],
    "mf_noise": [0],
    "reinit": [False],
    "mf_iterations": [200],
    "conv_threshold": [1e-8],

    "mf_acq_noise": [False],
    "acq_noise": [True],
    "use_power": True,
    "power_beta": [2],
    "sparse_sim_matrix": True,
    "mean_field_beta": [3],
    "info_gain_lambda": 1,
    "num_edges_info_gain": [10],
    "info_gain_pair_mode": ["entropy"],

    "dataset_name": "synthetic",
    "dataset_n_samples": 500,
    "dataset_n_clusters": [10],
    "dataset_class_balance": None,
    "dataset_class_sep": [1.5],
    "dataset_n_features": [10],
    "dataset_y_flip": [0],
}

start_index = er.generate_experiments(
    folder="../configs/ablation_fast",
    options_to_keep=[],
    start_index=start_index, 
    **config
)

# %%
from rac.experiment_data import ExperimentReader
er = ExperimentReader(metrics=["rand", "num_repeat_queries", "num_violations", "time_select_batch"])
data = er.read_all_data(folder="../experiment_results_local/ablation_req")

config = {
    "_experiment_name": "ablation_req",
    "_num_repeats": 14,
    "_n_workers": 14,
    "_local": True,
    "_verbose": True,
    "_overwrite": False,
    "_mode": "ac",

    "seed": 14,
    "batch_size": [0.0025],
    "noise_level": [0.6, 0.7],
    "clustering_alg": "CC",
    "warm_start": [0.01],
    "K_init": 10,
    "sim_init": [0.01],
    "sim_init_type": ["zeros"],
    "sample_size": 1,
    "infer_threshold": [-1],
    "start_inferring": [0],

    "acq_fn": ["unif","maxexp", "entropy", "info_gain_pairs_random", "info_gain_object"],

    "eps": [0.3, 0.8],
    "beta": [1],
    "tau": [1, 500],
    "num_maxmin_edges": -1,

    "alpha1": [1],
    "alpha2": [0.5],
    "alpha3": [1],

    "r": [0.02],
    "num_mc_samples": [5],
    "num_mc": [50],

    "num_mc_mf": [1],
    "mf_noise": [0],
    "reinit": [False],
    "mf_iterations": [200],
    "conv_threshold": [1e-8],

    "mf_acq_noise": [False],
    "acq_noise": [True],
    "use_power": True,
    "power_beta": [2],
    "sparse_sim_matrix": True,
    "mean_field_beta": [3],
    "info_gain_lambda": 1,
    "num_edges_info_gain": [10],
    "info_gain_pair_mode": ["entropy"],

    "dataset_name": "synthetic",
    "dataset_n_samples": 500,
    "dataset_n_clusters": [10],
    "dataset_class_balance": None,
    "dataset_class_sep": [1.5],
    "dataset_n_features": [10],
    "dataset_y_flip": [0],
}

er.generate_AL_curves2(
    data,
    save_location="../plots/requery/",
    categorize=["eps"],
    compare=["acq_fn", "tau"],
    vary=["x"],
    options_in_file_name=["noise_level"],
    auc=True,
    summary_method="auc_max_ind",
    indices=[], 
    threshold=1,
    err_style="band",
    marker="o",
    markersize=6,
    capsize=6,
    linestyle="solid",
    prop=False,
    varian=0,
    **config
)
# Out:
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:856: UserWarning: FixedFormatter should only be used together with FixedLocator
#   labels = []
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:856: UserWarning: FixedFormatter should only be used together with FixedLocator
#   labels = []
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:856: UserWarning: FixedFormatter should only be used together with FixedLocator
#   labels = []
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:856: UserWarning: FixedFormatter should only be used together with FixedLocator
#   labels = []
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:856: UserWarning: FixedFormatter should only be used together with FixedLocator
#   labels = []
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:856: UserWarning: FixedFormatter should only be used together with FixedLocator
#   labels = []
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:856: UserWarning: FixedFormatter should only be used together with FixedLocator
#   labels = []
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:856: UserWarning: FixedFormatter should only be used together with FixedLocator
#   labels = []
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:856: UserWarning: FixedFormatter should only be used together with FixedLocator
#   labels = []
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:856: UserWarning: FixedFormatter should only be used together with FixedLocator
#   labels = []
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:856: UserWarning: FixedFormatter should only be used together with FixedLocator
#   labels = []
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:856: UserWarning: FixedFormatter should only be used together with FixedLocator
#   labels = []
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:856: UserWarning: FixedFormatter should only be used together with FixedLocator
#   labels = []
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:856: UserWarning: FixedFormatter should only be used together with FixedLocator
#   labels = []
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:856: UserWarning: FixedFormatter should only be used together with FixedLocator
#   labels = []
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:856: UserWarning: FixedFormatter should only be used together with FixedLocator
#   labels = []

# %%
from rac.experiment_data import ExperimentReader
er = ExperimentReader(metrics=["rand", "num_repeat_queries", "num_violations", "time_select_batch"])
data = er.read_all_data(folder="../experiment_results_local/ablation22")

config = {
    "_experiment_name": "ablation22",
    "_num_repeats": 14,
    "_n_workers": 14,
    "_local": True,
    "_verbose": True,
    "_overwrite": False,
    "_mode": "ac",

    "seed": 14,
    "batch_size": [0.0025],
    "noise_level": [0.4],
    "clustering_alg": "CC",
    "warm_start": [0.01],
    "K_init": 10,
    "sim_init": [0.01],
    "sim_init_type": ["zeros"],
    "sample_size": 1,
    "infer_threshold": [-1],
    "start_inferring": [0],

    "acq_fn": ["unif", "maxmin", "maxexp", "entropy", "info_gain_pairs_random", "info_gain_object", "info_gain_pairs"],

    "eps": [0.8],
    "beta": [1],
    "tau": [1, 3, 7, 500],
    "num_maxmin_edges": -1,

    "alpha1": [1],
    "alpha2": [0.5],
    "alpha3": [1],

    "r": [0.02],
    "num_mc_samples": [5],
    "num_mc": [50],

    "num_mc_mf": [1],
    "mf_noise": [0],
    "reinit": [False],
    "mf_iterations": [200],
    "conv_threshold": [1e-8],

    "mf_acq_noise": [False],
    "acq_noise": [True],
    "use_power": True,
    "power_beta": [2],
    "sparse_sim_matrix": True,
    "mean_field_beta": [3],
    "info_gain_lambda": 1,
    "num_edges_info_gain": [10],
    "info_gain_pair_mode": ["entropy"],

    "dataset_name": "synthetic",
    "dataset_n_samples": 500,
    "dataset_n_clusters": [10],
    "dataset_class_balance": None,
    "dataset_class_sep": [1.5],
    "dataset_n_features": [10],
    "dataset_y_flip": [0],
}

er.generate_AL_curves2(
    data,
    save_location="../plots/requery/",
    categorize=[],
    compare=["tau"],
    vary=["x"],
    options_in_file_name=["acq_fn"],
    auc=True,
    summary_method="auc_max_ind",
    indices=[], 
    threshold=1,
    err_style="band",
    marker="o",
    markersize=6,
    capsize=6,
    linestyle="solid",
    prop=False,
    varian=0,
    **config
)
# Out:
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:800: UserWarning: FixedFormatter should only be used together with FixedLocator
#   #legs = ax.get_legend().get_texts()
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:800: UserWarning: FixedFormatter should only be used together with FixedLocator
#   #legs = ax.get_legend().get_texts()
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:800: UserWarning: FixedFormatter should only be used together with FixedLocator
#   #legs = ax.get_legend().get_texts()
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:800: UserWarning: FixedFormatter should only be used together with FixedLocator
#   #legs = ax.get_legend().get_texts()
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:800: UserWarning: FixedFormatter should only be used together with FixedLocator
#   #legs = ax.get_legend().get_texts()
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:800: UserWarning: FixedFormatter should only be used together with FixedLocator
#   #legs = ax.get_legend().get_texts()
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:800: UserWarning: FixedFormatter should only be used together with FixedLocator
#   #legs = ax.get_legend().get_texts()
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:800: UserWarning: FixedFormatter should only be used together with FixedLocator
#   #legs = ax.get_legend().get_texts()
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:800: UserWarning: FixedFormatter should only be used together with FixedLocator
#   #legs = ax.get_legend().get_texts()
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:800: UserWarning: FixedFormatter should only be used together with FixedLocator
#   #legs = ax.get_legend().get_texts()
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:800: UserWarning: FixedFormatter should only be used together with FixedLocator
#   #legs = ax.get_legend().get_texts()
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:800: UserWarning: FixedFormatter should only be used together with FixedLocator
#   #legs = ax.get_legend().get_texts()
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:800: UserWarning: FixedFormatter should only be used together with FixedLocator
#   #legs = ax.get_legend().get_texts()
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:800: UserWarning: FixedFormatter should only be used together with FixedLocator
#   #legs = ax.get_legend().get_texts()
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:800: UserWarning: FixedFormatter should only be used together with FixedLocator
#   #legs = ax.get_legend().get_texts()
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:800: UserWarning: FixedFormatter should only be used together with FixedLocator
#   #legs = ax.get_legend().get_texts()
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:800: UserWarning: FixedFormatter should only be used together with FixedLocator
#   #legs = ax.get_legend().get_texts()
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:800: UserWarning: FixedFormatter should only be used together with FixedLocator
#   #legs = ax.get_legend().get_texts()
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:800: UserWarning: FixedFormatter should only be used together with FixedLocator
#   #legs = ax.get_legend().get_texts()
# No data for these options @@@@@@@
# No data for these options @@@@@@@
# No data for these options @@@@@@@
# No data for these options @@@@@@@
# No data for these options @@@@@@@
# No data for these options @@@@@@@
# No data for these options @@@@@@@
# No data for these options @@@@@@@
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:800: UserWarning: FixedFormatter should only be used together with FixedLocator
#   #legs = ax.get_legend().get_texts()

# %% [markdown]
# # EIG ablation

# %%
config = {
    "_experiment_name": "ablation4",
    "_num_repeats": 14,
    "_n_workers": 14,
    "_local": True,
    "_verbose": True,
    "_overwrite": False,
    "_mode": "ac",

    "seed": 14,
    "batch_size": [0.0025],
    "noise_level": [0.4],
    "clustering_alg": "CC",
    "warm_start": [0.01],
    "K_init": 10,
    "sim_init": [0.01],
    "sim_init_type": ["zeros"],
    "sample_size": 1,
    "infer_threshold": [-1],
    "start_inferring": [0],

    "acq_fn": ["info_gain_object", "info_gain_pairs"],

    "eps": [0.8],
    "beta": [1],
    "tau": [3],
    "num_maxmin_edges": -1,

    "alpha1": [1],
    "alpha2": [0.5],
    "alpha3": [1],

    "r": [0.02],
    "num_mc_samples": [5],
    "num_mc": [50],

    "num_mc_mf": [1],
    "mf_noise": [0],
    "reinit": [False],
    "mf_iterations": [200],
    "conv_threshold": [1e-8],

    "mf_acq_noise": [False],
    "acq_noise": [True],
    "use_power": True,
    "power_beta": [1],
    "sparse_sim_matrix": True,
    "mean_field_beta": [3],
    "info_gain_lambda": 1,
    "num_edges_info_gain": [1, 3, 5, 10, 20, 50],
    "info_gain_pair_mode": ["entropy"],

    "dataset_name": "synthetic",
    "dataset_n_samples": 500,
    "dataset_n_clusters": [10],
    "dataset_class_balance": None,
    "dataset_class_sep": [1.5],
    "dataset_n_features": [10],
    "dataset_y_flip": [0],
}

start_index = er.generate_experiments(
    folder="../configs/ablation",
    options_to_keep=[],
    start_index=start_index, 
    **config
)

# %%
from rac.experiment_data import ExperimentReader
er = ExperimentReader(metrics=["rand", "num_repeat_queries", "num_violations", "time_select_batch"])
data = er.read_all_data(folder="../experiment_results_local/ablation4")

config = {
    "_experiment_name": "ablation4",
    "_num_repeats": 14,
    "_n_workers": 14,
    "_local": True,
    "_verbose": True,
    "_overwrite": False,
    "_mode": "ac",

    "seed": 14,
    "batch_size": [0.0025],
    "noise_level": [0.4],
    "clustering_alg": "CC",
    "warm_start": [0.01],
    "K_init": 10,
    "sim_init": [0.01],
    "sim_init_type": ["zeros"],
    "sample_size": 1,
    "infer_threshold": [-1],
    "start_inferring": [0],

    "acq_fn": ["info_gain_object", "info_gain_pairs"],

    "eps": [0.8],
    "beta": [1],
    "tau": [3],
    "num_maxmin_edges": -1,

    "alpha1": [1],
    "alpha2": [0.5],
    "alpha3": [1],

    "r": [0.02],
    "num_mc_samples": [5],
    "num_mc": [50],

    "num_mc_mf": [1],
    "mf_noise": [0],
    "reinit": [False],
    "mf_iterations": [200],
    "conv_threshold": [1e-8],

    "mf_acq_noise": [False],
    "acq_noise": [True],
    "use_power": True,
    "power_beta": [1],
    "sparse_sim_matrix": True,
    "mean_field_beta": [3],
    "info_gain_lambda": 1,
    "num_edges_info_gain": [1, 3, 5, 10, 20],
    "info_gain_pair_mode": ["entropy"],

    "dataset_name": "synthetic",
    "dataset_n_samples": 500,
    "dataset_n_clusters": [10],
    "dataset_class_balance": None,
    "dataset_class_sep": [1.5],
    "dataset_n_features": [10],
    "dataset_y_flip": [0],
}

er.generate_AL_curves4(
    data,
    save_location="../plots/eig/",
    categorize=[],
    compare=["num_edges_info_gain"],
    vary=["x"],
    options_in_file_name=["acq_fn"],
    auc=True,
    summary_method="auc_max_ind",
    indices=[], 
    threshold=1,
    err_style="band",
    marker="o",
    markersize=6,
    capsize=6,
    linestyle="solid",
    prop=False,
    varian=0.5,
    **config
)
# Out:
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:1374: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:1374: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:1374: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:1374: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:1374: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:1374: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:1374: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:1374: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)

# %% [markdown]
# # JEIG ablation

# %%
config = {
    "_experiment_name": "ablation5",
    "_num_repeats": 14,
    "_n_workers": 14,
    "_local": True,
    "_verbose": True,
    "_overwrite": False,
    "_mode": "ac",

    "seed": 14,
    "batch_size": [0.0025],
    "noise_level": [0.4],
    "clustering_alg": "CC",
    "warm_start": [0.01],
    "K_init": 10,
    "sim_init": [0.01],
    "sim_init_type": ["zeros"],
    "sample_size": 1,
    "infer_threshold": [-1],
    "start_inferring": [0],

    "acq_fn": ["info_gain_pairs_random"],

    "eps": [0.8],
    "beta": [1],
    "tau": [3],
    "num_maxmin_edges": -1,

    "alpha1": [1],
    "alpha2": [0.5],
    "alpha3": [1],

    "r": [0.002, 0.02, 0.2, 0.6],
    "num_mc_samples": [1, 5],
    "num_mc": [1, 10, 50],

    "num_mc_mf": [1],
    "mf_noise": [0],
    "reinit": [False],
    "mf_iterations": [200],
    "conv_threshold": [1e-8],

    "mf_acq_noise": [False],
    "acq_noise": [True],
    "use_power": True,
    "power_beta": [1, 2],
    "sparse_sim_matrix": True,
    "mean_field_beta": [3],
    "info_gain_lambda": 1,
    "num_edges_info_gain": [10],
    "info_gain_pair_mode": ["entropy"],

    "dataset_name": "synthetic",
    "dataset_n_samples": 500,
    "dataset_n_clusters": [10],
    "dataset_class_balance": None,
    "dataset_class_sep": [1.5],
    "dataset_n_features": [10],
    "dataset_y_flip": [0],
}

start_index = er.generate_experiments(
    folder="../configs/ablation_fast",
    options_to_keep=[],
    start_index=start_index, 
    **config
)

# %%
from rac.experiment_data import ExperimentReader
er = ExperimentReader(metrics=["rand", "num_repeat_queries", "num_violations", "time_select_batch"])
data = er.read_all_data(folder="../experiment_results_local/ablation5")

config = {
    "_experiment_name": "ablation5",
    "_num_repeats": 14,
    "_n_workers": 14,
    "_local": True,
    "_verbose": True,
    "_overwrite": False,
    "_mode": "ac",

    "seed": 14,
    "batch_size": [0.0025],
    "noise_level": [0.4],
    "clustering_alg": "CC",
    "warm_start": [0.01],
    "K_init": 10,
    "sim_init": [0.01],
    "sim_init_type": ["zeros"],
    "sample_size": 1,
    "infer_threshold": [-1],
    "start_inferring": [0],

    "acq_fn": ["info_gain_pairs_random"],

    "eps": [0.8],
    "beta": [1],
    "tau": [3],
    "num_maxmin_edges": -1,

    "alpha1": [1],
    "alpha2": [0.5],
    "alpha3": [1],

    "r": [0.002, 0.02, 0.2, 0.6],
    "num_mc_samples": [1, 5],
    "num_mc": [1, 10, 50],

    "num_mc_mf": [1],
    "mf_noise": [0],
    "reinit": [False],
    "mf_iterations": [200],
    "conv_threshold": [1e-8],

    "mf_acq_noise": [False],
    "acq_noise": [True],
    "use_power": True,
    "power_beta": [1, 2],
    "sparse_sim_matrix": True,
    "mean_field_beta": [3],
    "info_gain_lambda": 1,
    "num_edges_info_gain": [10],
    "info_gain_pair_mode": ["entropy"],

    "dataset_name": "synthetic",
    "dataset_n_samples": 500,
    "dataset_n_clusters": [10],
    "dataset_class_balance": None,
    "dataset_class_sep": [1.5],
    "dataset_n_features": [10],
    "dataset_y_flip": [0],
}

er.generate_AL_curves4(
    data,
    save_location="../plots/jeig1/",
    categorize=[],
    compare=["r"],
    vary=["x"],
    options_in_file_name=["acq_fn", "power_beta"],
    auc=True,
    summary_method="auc_max_ind",
    indices=[], 
    threshold=1,
    err_style="band",
    marker="o",
    markersize=6,
    capsize=6,
    linestyle="solid",
    prop=False,
    varian=0.5,
    **config
)
# Out:
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:1372: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:1372: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:1372: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:1372: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:1372: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:1372: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:1372: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:1372: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:1372: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:1372: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:1372: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:1372: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:1372: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:1372: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:1372: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:1372: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:1372: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:1372: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:1372: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:1372: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:1372: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:1372: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:1372: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:1372: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:1372: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:1372: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:1372: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:1372: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:1372: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:1372: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:1372: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:1372: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:1372: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:1372: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:1372: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:1372: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:1372: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:1372: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:1372: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:1372: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:1372: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:1372: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:1372: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:1372: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:1372: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:1372: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:1372: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:1372: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)

# %% [markdown]
# # small batch size

# %%
config = {
    "_experiment_name": "ablation6",
    "_num_repeats": 14,
    "_n_workers": 14,
    "_local": True,
    "_verbose": True,
    "_overwrite": False,
    "_mode": "ac",

    "seed": 14,
    "batch_size": [5],
    "noise_level": [0.4],
    "clustering_alg": "CC",
    "warm_start": [0.01],
    "K_init": 10,
    "sim_init": [0.01],
    "sim_init_type": ["zeros"],
    "sample_size": 1,
    "infer_threshold": [-1],
    "start_inferring": [0],

    "acq_fn": ["unif", "entropy", "info_gain_pairs_random", "info_gain_object", "info_gain_pairs"],

    "eps": [0.8],
    "beta": [1],
    "tau": [3],
    "num_maxmin_edges": -1,

    "alpha1": [1],
    "alpha2": [0.5],
    "alpha3": [1],

    "r": [0.002, 0.02, 0.2],
    "num_mc_samples": [5],
    "num_mc": [50, 100],

    "num_mc_mf": [1],
    "mf_noise": [0],
    "reinit": [False],
    "mf_iterations": [200],
    "conv_threshold": [1e-8],

    "mf_acq_noise": [False],
    "acq_noise": [True, False],
    "use_power": True,
    "power_beta": [1, 2],
    "sparse_sim_matrix": True,
    "mean_field_beta": [3],
    "info_gain_lambda": 1,
    "num_edges_info_gain": [-1],
    "info_gain_pair_mode": ["entropy"],

    "dataset_name": "synthetic",
    "dataset_n_samples": 70,
    "dataset_n_clusters": [5],
    "dataset_class_balance": None,
    "dataset_class_sep": [1.5],
    "dataset_n_features": [10],
    "dataset_y_flip": [0],
}

start_index = er.generate_experiments(
    folder="../configs/ablation_fast",
    options_to_keep=[],
    start_index=start_index, 
    **config
)

# %%
from rac.experiment_data import ExperimentReader
er = ExperimentReader(metrics=["rand", "num_repeat_queries", "num_violations", "time_select_batch"])
data = er.read_all_data(folder="../experiment_results_local/ablation6")

config = {
    "_experiment_name": "ablation6",
    "_num_repeats": 14,
    "_n_workers": 14,
    "_local": True,
    "_verbose": True,
    "_overwrite": False,
    "_mode": "ac",

    "seed": 14,
    "batch_size": [5],
    "noise_level": [0.4],
    "clustering_alg": "CC",
    "warm_start": [0.01],
    "K_init": 10,
    "sim_init": [0.01],
    "sim_init_type": ["zeros"],
    "sample_size": 1,
    "infer_threshold": [-1],
    "start_inferring": [0],

    "acq_fn": ["unif", "entropy", "info_gain_pairs_random", "info_gain_object", "info_gain_pairs"],

    "eps": [0.8],
    "beta": [1],
    "tau": [3],
    "num_maxmin_edges": -1,

    "alpha1": [1],
    "alpha2": [0.5],
    "alpha3": [1],

    "r": [0.002, 0.02, 0.2],
    "num_mc_samples": [5],
    "num_mc": [50, 100],

    "num_mc_mf": [1],
    "mf_noise": [0],
    "reinit": [False],
    "mf_iterations": [200],
    "conv_threshold": [1e-8],

    "mf_acq_noise": [False],
    "acq_noise": [True, False],
    "use_power": True,
    "power_beta": [1, 2],
    "sparse_sim_matrix": True,
    "mean_field_beta": [3],
    "info_gain_lambda": 1,
    "num_edges_info_gain": [-1],
    "info_gain_pair_mode": ["entropy"],

    "dataset_name": "synthetic",
    "dataset_n_samples": 70,
    "dataset_n_clusters": [5],
    "dataset_class_balance": None,
    "dataset_class_sep": [1.5],
    "dataset_n_features": [10],
    "dataset_y_flip": [0],
}

er.generate_AL_curves2(
    data,
    save_location="../plots/small/",
    categorize=[],
    compare=["acq_fn"],
    vary=["x"],
    options_in_file_name=["acq_noise", "r", "num_mc", "power_beta"],
    auc=True,
    summary_method="auc_max_ind",
    indices=[], 
    threshold=1,
    err_style="band",
    marker="o",
    markersize=6,
    capsize=6,
    linestyle="solid",
    prop=False,
    varian=0.5,
    **config
)
# Out:
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:800: UserWarning: FixedFormatter should only be used together with FixedLocator
#   #legs = ax.get_legend().get_texts()
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:800: UserWarning: FixedFormatter should only be used together with FixedLocator
#   #legs = ax.get_legend().get_texts()
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:800: UserWarning: FixedFormatter should only be used together with FixedLocator
#   #legs = ax.get_legend().get_texts()
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:800: UserWarning: FixedFormatter should only be used together with FixedLocator
#   #legs = ax.get_legend().get_texts()
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:800: UserWarning: FixedFormatter should only be used together with FixedLocator
#   #legs = ax.get_legend().get_texts()
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:800: UserWarning: FixedFormatter should only be used together with FixedLocator
#   #legs = ax.get_legend().get_texts()
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:800: UserWarning: FixedFormatter should only be used together with FixedLocator
#   #legs = ax.get_legend().get_texts()
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:800: UserWarning: FixedFormatter should only be used together with FixedLocator
#   #legs = ax.get_legend().get_texts()
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:800: UserWarning: FixedFormatter should only be used together with FixedLocator
#   #legs = ax.get_legend().get_texts()
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:800: UserWarning: FixedFormatter should only be used together with FixedLocator
#   #legs = ax.get_legend().get_texts()
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:800: UserWarning: FixedFormatter should only be used together with FixedLocator
#   #legs = ax.get_legend().get_texts()
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:800: UserWarning: FixedFormatter should only be used together with FixedLocator
#   #legs = ax.get_legend().get_texts()
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:800: UserWarning: FixedFormatter should only be used together with FixedLocator
#   #legs = ax.get_legend().get_texts()
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:800: UserWarning: FixedFormatter should only be used together with FixedLocator
#   #legs = ax.get_legend().get_texts()
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:800: UserWarning: FixedFormatter should only be used together with FixedLocator
#   #legs = ax.get_legend().get_texts()
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:800: UserWarning: FixedFormatter should only be used together with FixedLocator
#   #legs = ax.get_legend().get_texts()
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:800: UserWarning: FixedFormatter should only be used together with FixedLocator
#   #legs = ax.get_legend().get_texts()
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:800: UserWarning: FixedFormatter should only be used together with FixedLocator
#   #legs = ax.get_legend().get_texts()
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:800: UserWarning: FixedFormatter should only be used together with FixedLocator
#   #legs = ax.get_legend().get_texts()
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:800: UserWarning: FixedFormatter should only be used together with FixedLocator
#   #legs = ax.get_legend().get_texts()
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:800: UserWarning: FixedFormatter should only be used together with FixedLocator
#   #legs = ax.get_legend().get_texts()
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:800: UserWarning: FixedFormatter should only be used together with FixedLocator
#   #legs = ax.get_legend().get_texts()
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:800: UserWarning: FixedFormatter should only be used together with FixedLocator
#   #legs = ax.get_legend().get_texts()
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:800: UserWarning: FixedFormatter should only be used together with FixedLocator
#   #legs = ax.get_legend().get_texts()
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:800: UserWarning: FixedFormatter should only be used together with FixedLocator
#   #legs = ax.get_legend().get_texts()
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:800: UserWarning: FixedFormatter should only be used together with FixedLocator
#   #legs = ax.get_legend().get_texts()
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:800: UserWarning: FixedFormatter should only be used together with FixedLocator
#   #legs = ax.get_legend().get_texts()
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:800: UserWarning: FixedFormatter should only be used together with FixedLocator
#   #legs = ax.get_legend().get_texts()
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:800: UserWarning: FixedFormatter should only be used together with FixedLocator
#   #legs = ax.get_legend().get_texts()
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:800: UserWarning: FixedFormatter should only be used together with FixedLocator
#   #legs = ax.get_legend().get_texts()
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:800: UserWarning: FixedFormatter should only be used together with FixedLocator
#   #legs = ax.get_legend().get_texts()
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:800: UserWarning: FixedFormatter should only be used together with FixedLocator
#   #legs = ax.get_legend().get_texts()
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:800: UserWarning: FixedFormatter should only be used together with FixedLocator
#   #legs = ax.get_legend().get_texts()
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:800: UserWarning: FixedFormatter should only be used together with FixedLocator
#   #legs = ax.get_legend().get_texts()
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:800: UserWarning: FixedFormatter should only be used together with FixedLocator
#   #legs = ax.get_legend().get_texts()
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:800: UserWarning: FixedFormatter should only be used together with FixedLocator
#   #legs = ax.get_legend().get_texts()
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:800: UserWarning: FixedFormatter should only be used together with FixedLocator
#   #legs = ax.get_legend().get_texts()
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:800: UserWarning: FixedFormatter should only be used together with FixedLocator
#   #legs = ax.get_legend().get_texts()
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:800: UserWarning: FixedFormatter should only be used together with FixedLocator
#   #legs = ax.get_legend().get_texts()
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:800: UserWarning: FixedFormatter should only be used together with FixedLocator
#   #legs = ax.get_legend().get_texts()
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:800: UserWarning: FixedFormatter should only be used together with FixedLocator
#   #legs = ax.get_legend().get_texts()
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:800: UserWarning: FixedFormatter should only be used together with FixedLocator
#   #legs = ax.get_legend().get_texts()
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:800: UserWarning: FixedFormatter should only be used together with FixedLocator
#   #legs = ax.get_legend().get_texts()
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:800: UserWarning: FixedFormatter should only be used together with FixedLocator
#   #legs = ax.get_legend().get_texts()
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:800: UserWarning: FixedFormatter should only be used together with FixedLocator
#   #legs = ax.get_legend().get_texts()
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:800: UserWarning: FixedFormatter should only be used together with FixedLocator
#   #legs = ax.get_legend().get_texts()
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:800: UserWarning: FixedFormatter should only be used together with FixedLocator
#   #legs = ax.get_legend().get_texts()
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:800: UserWarning: FixedFormatter should only be used together with FixedLocator
#   #legs = ax.get_legend().get_texts()
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:800: UserWarning: FixedFormatter should only be used together with FixedLocator
#   #legs = ax.get_legend().get_texts()
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:800: UserWarning: FixedFormatter should only be used together with FixedLocator
#   #legs = ax.get_legend().get_texts()
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:800: UserWarning: FixedFormatter should only be used together with FixedLocator
#   #legs = ax.get_legend().get_texts()
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:800: UserWarning: FixedFormatter should only be used together with FixedLocator
#   #legs = ax.get_legend().get_texts()
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:800: UserWarning: FixedFormatter should only be used together with FixedLocator
#   #legs = ax.get_legend().get_texts()
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:800: UserWarning: FixedFormatter should only be used together with FixedLocator
#   #legs = ax.get_legend().get_texts()
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:800: UserWarning: FixedFormatter should only be used together with FixedLocator
#   #legs = ax.get_legend().get_texts()
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:800: UserWarning: FixedFormatter should only be used together with FixedLocator
#   #legs = ax.get_legend().get_texts()
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:800: UserWarning: FixedFormatter should only be used together with FixedLocator
#   #legs = ax.get_legend().get_texts()
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:800: UserWarning: FixedFormatter should only be used together with FixedLocator
#   #legs = ax.get_legend().get_texts()
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:800: UserWarning: FixedFormatter should only be used together with FixedLocator
#   #legs = ax.get_legend().get_texts()
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:800: UserWarning: FixedFormatter should only be used together with FixedLocator
#   #legs = ax.get_legend().get_texts()
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:800: UserWarning: FixedFormatter should only be used together with FixedLocator
#   #legs = ax.get_legend().get_texts()
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:800: UserWarning: FixedFormatter should only be used together with FixedLocator
#   #legs = ax.get_legend().get_texts()
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:800: UserWarning: FixedFormatter should only be used together with FixedLocator
#   #legs = ax.get_legend().get_texts()
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:800: UserWarning: FixedFormatter should only be used together with FixedLocator
#   #legs = ax.get_legend().get_texts()
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:800: UserWarning: FixedFormatter should only be used together with FixedLocator
#   #legs = ax.get_legend().get_texts()
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:800: UserWarning: FixedFormatter should only be used together with FixedLocator
#   #legs = ax.get_legend().get_texts()
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:800: UserWarning: FixedFormatter should only be used together with FixedLocator
#   #legs = ax.get_legend().get_texts()
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:800: UserWarning: FixedFormatter should only be used together with FixedLocator
#   #legs = ax.get_legend().get_texts()
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:800: UserWarning: FixedFormatter should only be used together with FixedLocator
#   #legs = ax.get_legend().get_texts()
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:800: UserWarning: FixedFormatter should only be used together with FixedLocator
#   #legs = ax.get_legend().get_texts()
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:800: UserWarning: FixedFormatter should only be used together with FixedLocator
#   #legs = ax.get_legend().get_texts()
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:800: UserWarning: FixedFormatter should only be used together with FixedLocator
#   #legs = ax.get_legend().get_texts()
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:800: UserWarning: FixedFormatter should only be used together with FixedLocator
#   #legs = ax.get_legend().get_texts()
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:800: UserWarning: FixedFormatter should only be used together with FixedLocator
#   #legs = ax.get_legend().get_texts()
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:800: UserWarning: FixedFormatter should only be used together with FixedLocator
#   #legs = ax.get_legend().get_texts()
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:800: UserWarning: FixedFormatter should only be used together with FixedLocator
#   #legs = ax.get_legend().get_texts()
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:800: UserWarning: FixedFormatter should only be used together with FixedLocator
#   #legs = ax.get_legend().get_texts()
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:800: UserWarning: FixedFormatter should only be used together with FixedLocator
#   #legs = ax.get_legend().get_texts()
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:800: UserWarning: FixedFormatter should only be used together with FixedLocator
#   #legs = ax.get_legend().get_texts()
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:800: UserWarning: FixedFormatter should only be used together with FixedLocator
#   #legs = ax.get_legend().get_texts()
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:800: UserWarning: FixedFormatter should only be used together with FixedLocator
#   #legs = ax.get_legend().get_texts()
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:800: UserWarning: FixedFormatter should only be used together with FixedLocator
#   #legs = ax.get_legend().get_texts()
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:800: UserWarning: FixedFormatter should only be used together with FixedLocator
#   #legs = ax.get_legend().get_texts()
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:800: UserWarning: FixedFormatter should only be used together with FixedLocator
#   #legs = ax.get_legend().get_texts()
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:800: UserWarning: FixedFormatter should only be used together with FixedLocator
#   #legs = ax.get_legend().get_texts()
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:800: UserWarning: FixedFormatter should only be used together with FixedLocator
#   #legs = ax.get_legend().get_texts()
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:800: UserWarning: FixedFormatter should only be used together with FixedLocator
#   #legs = ax.get_legend().get_texts()
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:800: UserWarning: FixedFormatter should only be used together with FixedLocator
#   #legs = ax.get_legend().get_texts()
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:800: UserWarning: FixedFormatter should only be used together with FixedLocator
#   #legs = ax.get_legend().get_texts()
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:800: UserWarning: FixedFormatter should only be used together with FixedLocator
#   #legs = ax.get_legend().get_texts()
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:800: UserWarning: FixedFormatter should only be used together with FixedLocator
#   #legs = ax.get_legend().get_texts()
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:800: UserWarning: FixedFormatter should only be used together with FixedLocator
#   #legs = ax.get_legend().get_texts()
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:800: UserWarning: FixedFormatter should only be used together with FixedLocator
#   #legs = ax.get_legend().get_texts()
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:800: UserWarning: FixedFormatter should only be used together with FixedLocator
#   #legs = ax.get_legend().get_texts()
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:800: UserWarning: FixedFormatter should only be used together with FixedLocator
#   #legs = ax.get_legend().get_texts()
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:800: UserWarning: FixedFormatter should only be used together with FixedLocator
#   #legs = ax.get_legend().get_texts()

# %% [markdown]
# # beta

# %%
start_index = 1
config = {
    "_experiment_name": "ablation9",
    "_num_repeats": 14,
    "_n_workers": 14,
    "_local": True,
    "_verbose": True,
    "_overwrite": False,
    "_mode": "ac",

    "seed": 14,
    "batch_size": [0.0025],
    "noise_level": [0.4],
    "clustering_alg": "CC",
    "warm_start": [0.01],
    "K_init": 10,
    "sim_init": [0.01],
    "sim_init_type": ["zeros"],
    "sample_size": 1,
    "infer_threshold": [-1],
    "start_inferring": [0],

    "acq_fn": ["entropy", "info_gain_pairs_random", "info_gain_object"],

    "eps": [0.8],
    "beta": [1],
    "tau": [1, 3],
    "num_maxmin_edges": -1,

    "alpha1": [1],
    "alpha2": [0.5],
    "alpha3": [1],

    "r": [0.02],
    "num_mc_samples": [5],
    "num_mc": [50],

    "num_mc_mf": [1],
    "mf_noise": [0],
    "reinit": [False],
    "mf_iterations": [200],
    "conv_threshold": [1e-8],

    "mf_acq_noise": [False],
    "acq_noise": [True],
    "use_power": True,
    "power_beta": [2],
    "sparse_sim_matrix": True,
    "mean_field_beta": [0.5, 1, 3, 5, 10, 100],
    "info_gain_lambda": 1,
    "num_edges_info_gain": [10],
    "info_gain_pair_mode": ["entropy"],

    "dataset_name": "synthetic",
    "dataset_n_samples": 500,
    "dataset_n_clusters": [10],
    "dataset_class_balance": None,
    "dataset_class_sep": [1.5],
    "dataset_n_features": [10],
    "dataset_y_flip": [0],
}

start_index = er.generate_experiments(
    folder="../configs/ablation_fast",
    options_to_keep=[],
    start_index=start_index, 
    **config
)

# %%
from rac.experiment_data import ExperimentReader
er = ExperimentReader(metrics=["rand", "num_repeat_queries", "num_violations", "time_select_batch"])
data = er.read_all_data(folder="../experiment_results_local/ablation9")

config = {
    "_experiment_name": "ablation9",
    "_num_repeats": 14,
    "_n_workers": 14,
    "_local": True,
    "_verbose": True,
    "_overwrite": False,
    "_mode": "ac",

    "seed": 14,
    "batch_size": [0.0025],
    "noise_level": [0.4],
    "clustering_alg": "CC",
    "warm_start": [0.01],
    "K_init": 10,
    "sim_init": [0.01],
    "sim_init_type": ["zeros"],
    "sample_size": 1,
    "infer_threshold": [-1],
    "start_inferring": [0],

    "acq_fn": ["entropy", "info_gain_pairs_random", "info_gain_object"],

    "eps": [0.8],
    "beta": [1],
    "tau": [1, 3],
    "num_maxmin_edges": -1,

    "alpha1": [1],
    "alpha2": [0.5],
    "alpha3": [1],

    "r": [0.02],
    "num_mc_samples": [5],
    "num_mc": [50],

    "num_mc_mf": [1],
    "mf_noise": [0],
    "reinit": [False],
    "mf_iterations": [200],
    "conv_threshold": [1e-8],

    "mf_acq_noise": [False],
    "acq_noise": [True],
    "use_power": True,
    "power_beta": [2],
    "sparse_sim_matrix": True,
    "mean_field_beta": [0.5, 1, 3, 5, 10, 100],
    "info_gain_lambda": 1,
    "num_edges_info_gain": [10],
    "info_gain_pair_mode": ["entropy"],

    "dataset_name": "synthetic",
    "dataset_n_samples": 500,
    "dataset_n_clusters": [10],
    "dataset_class_balance": None,
    "dataset_class_sep": [1.5],
    "dataset_n_features": [10],
    "dataset_y_flip": [0],
}

er.generate_AL_curves4(
    data,
    save_location="../plots/beta/",
    categorize=[],
    compare=["mean_field_beta"],
    vary=["x"],
    options_in_file_name=["acq_fn", "tau"],
    auc=True,
    summary_method="auc_max_ind",
    indices=[], 
    threshold=1,
    err_style="band",
    marker="o",
    markersize=6,
    capsize=6,
    linestyle="solid",
    prop=False,
    varian=0.5,
    **config
)
# Out:
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:1372: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:1372: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:1372: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:1372: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:1372: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:1372: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:1372: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:1372: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:1372: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:1372: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:1372: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:1372: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:1372: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:1372: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:1372: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:1372: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:1372: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:1372: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:1372: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:1372: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:1372: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:1372: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:1372: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:1372: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)

# %% [markdown]
# # alternative init

# %%
start_index = 1
from rac.experiment_data import ExperimentReader
er = ExperimentReader(metrics=["rand"])
config = {
    "_experiment_name": "ablation_alt",
    "_num_repeats": 14,
    "_n_workers": 14,
    "_local": True,
    "_verbose": True,
    "_overwrite": False,
    "_mode": "ac",

    "seed": 14,
    "batch_size": [0.0025],
    "noise_level": [0.4, 0.6],
    "clustering_alg": "CC",
    "warm_start": [0, 0.01],
    "K_init": 10,
    "sim_init": [0.01, 0.001],
    "sim_init_type": ["zeros", "kmeans"],
    "sample_size": 1,
    "infer_threshold": [-1],
    "start_inferring": [0],

    "acq_fn": ["unif", "maxmin", "maxexp", "entropy", "info_gain_pairs_random", "info_gain_object", "info_gain_pairs"],

    "eps": [0.8],
    "beta": [1],
    "tau": [3],
    "num_maxmin_edges": -1,

    "alpha1": [1],
    "alpha2": [0.5],
    "alpha3": [1],

    "r": [0.02],
    "num_mc_samples": [5],
    "num_mc": [50],

    "num_mc_mf": [1],
    "mf_noise": [0],
    "reinit": [False],
    "mf_iterations": [200],
    "conv_threshold": [1e-8],

    "mf_acq_noise": [False],
    "acq_noise": [True],
    "use_power": True,
    "power_beta": [2],
    "sparse_sim_matrix": True,
    "mean_field_beta": [3],
    "info_gain_lambda": 1,
    "num_edges_info_gain": [20],
    "info_gain_pair_mode": ["entropy"],

    "dataset_name": "synthetic",
    "dataset_n_samples": 500,
    "dataset_n_clusters": [10],
    "dataset_class_balance": None,
    "dataset_class_sep": [1.5],
    "dataset_n_features": [10],
    "dataset_y_flip": [0],
}

start_index = er.generate_experiments(
    folder="../configs/ablation_f",
    options_to_keep=[],
    start_index=start_index, 
    **config
)

# %%
from rac.experiment_data import ExperimentReader
er = ExperimentReader(metrics=["rand", "num_repeat_queries", "num_violations", "time_select_batch"])
data = er.read_all_data(folder="../experiment_results_local/ablation_alt")

config = {
    "_experiment_name": "ablation_alt",
    "_num_repeats": 14,
    "_n_workers": 14,
    "_local": True,
    "_verbose": True,
    "_overwrite": False,
    "_mode": "ac",

    "seed": 14,
    "batch_size": [0.0025],
    "noise_level": [0.4, 0.6],
    "clustering_alg": "CC",
    "warm_start": [0, 0.01],
    "K_init": 10,
    "sim_init": [0.01, 0.001],
    "sim_init_type": ["zeros", "kmeans"],
    "sample_size": 1,
    "infer_threshold": [-1],
    "start_inferring": [0],

    "acq_fn": ["unif", "maxmin", "maxexp", "entropy", "info_gain_pairs_random", "info_gain_object", "info_gain_pairs"],

    "eps": [0.8],
    "beta": [1],
    "tau": [3],
    "num_maxmin_edges": -1,

    "alpha1": [1],
    "alpha2": [0.5],
    "alpha3": [1],

    "r": [0.02],
    "num_mc_samples": [5],
    "num_mc": [50],

    "num_mc_mf": [1],
    "mf_noise": [0],
    "reinit": [False],
    "mf_iterations": [200],
    "conv_threshold": [1e-8],

    "mf_acq_noise": [False],
    "acq_noise": [True],
    "use_power": True,
    "power_beta": [2],
    "sparse_sim_matrix": True,
    "mean_field_beta": [3],
    "info_gain_lambda": 1,
    "num_edges_info_gain": [20],
    "info_gain_pair_mode": ["entropy"],

    "dataset_name": "synthetic",
    "dataset_n_samples": 500,
    "dataset_n_clusters": [10],
    "dataset_class_balance": None,
    "dataset_class_sep": [1.5],
    "dataset_n_features": [10],
    "dataset_y_flip": [0],
}

er.generate_AL_curves2(
    data,
    save_location="../plots/alternative2/",
    categorize=[],
    compare=["warm_start", "sim_init", "sim_init_type"],
    vary=["x"],
    options_in_file_name=["acq_fn", "noise_level"],
    auc=True,
    summary_method="auc_max_ind",
    indices=[], 
    threshold=1,
    err_style="band",
    marker="o",
    markersize=6,
    capsize=6,
    linestyle="solid",
    prop=False,
    varian=0.5,
    **config
)
# Out:
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:802: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:802: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:802: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:802: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:802: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:802: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:802: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:802: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:802: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:802: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:802: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:802: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:802: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:802: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:802: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:802: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:802: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:802: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:802: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:802: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:802: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:802: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:802: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:802: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:802: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:802: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:802: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:802: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:802: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:802: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:802: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:802: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:802: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:802: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:802: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:802: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:802: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:802: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:802: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:802: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:802: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:802: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:802: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:802: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:802: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:802: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:802: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:802: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:802: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:802: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:802: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:802: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# No data for these options @@@@@@@
# No data for these options @@@@@@@
# No data for these options @@@@@@@
# No data for these options @@@@@@@
