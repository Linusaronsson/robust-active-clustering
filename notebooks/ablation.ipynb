# %% [markdown]
# # batch size

# %%
from rac.experiment_data import ExperimentReader
er = ExperimentReader(metrics=["rand"])

start_index = 1

config = {
    "_experiment_name": "ablation1",
    "_num_repeats": 14,
    "_n_workers": 14,
    "_local": True,
    "_verbose": True,
    "_overwrite": False,
    "_mode": "ac",

    "seed": 14,
    "batch_size": [100, 500, 1000, 2000],
    "noise_level": [0.4],
    "clustering_alg": "CC",
    "warm_start": [0.01],
    "K_init": 10,
    "sim_init": [0.01],
    "sim_init_type": ["zeros"],
    "sample_size": 1,
    "infer_threshold": [-1],
    "start_inferring": [0],

    "acq_fn": ["unif", "maxmin", "maxexp", "entropy", "info_gain_pairs_random", "info_gain_object", "info_gain_pairs"],

    "eps": [0.8],
    "beta": [1],
    "tau": [3],
    "num_maxmin_edges": -1,

    "alpha1": [1],
    "alpha2": [0.5],
    "alpha3": [1],

    "r": [0.02],
    "num_mc_samples": [5],
    "num_mc": [50],

    "num_mc_mf": [1],
    "mf_noise": [0],
    "reinit": [False],
    "mf_iterations": [200],
    "conv_threshold": [1e-8],

    "mf_acq_noise": [False],
    "acq_noise": [True],
    "use_power": True,
    "power_beta": [2],
    "sparse_sim_matrix": True,
    "mean_field_beta": [3],
    "info_gain_lambda": 1,
    "num_edges_info_gain": [20],
    "info_gain_pair_mode": ["entropy"],

    "dataset_name": "synthetic",
    "dataset_n_samples": 500,
    "dataset_n_clusters": [10],
    "dataset_class_balance": None,
    "dataset_class_sep": [1.5],
    "dataset_n_features": [10],
    "dataset_y_flip": [0],
}

start_index = er.generate_experiments(
    folder="../configs/ablation",
    options_to_keep=[],
    start_index=start_index, 
    **config
)

# %% [markdown]
# # noise level

# %%
config = {
    "_experiment_name": "ablation2",
    "_num_repeats": 14,
    "_n_workers": 14,
    "_local": True,
    "_verbose": True,
    "_overwrite": False,
    "_mode": "ac",

    "seed": 14,
    "batch_size": [0.0025],
    "noise_level": [0.0, 0.2, 0.4, 0.6, 0.8],
    "clustering_alg": "CC",
    "warm_start": [0.01],
    "K_init": 10,
    "sim_init": [0.01],
    "sim_init_type": ["zeros"],
    "sample_size": 1,
    "infer_threshold": [-1],
    "start_inferring": [0],

    "acq_fn": ["unif", "maxmin", "maxexp", "entropy", "info_gain_pairs_random", "info_gain_object", "info_gain_pairs"],

    "eps": [0.8],
    "beta": [1],
    "tau": [3],
    "num_maxmin_edges": -1,

    "alpha1": [1],
    "alpha2": [0.5],
    "alpha3": [1],

    "r": [0.02],
    "num_mc_samples": [5],
    "num_mc": [50],

    "num_mc_mf": [1],
    "mf_noise": [0],
    "reinit": [False],
    "mf_iterations": [200],
    "conv_threshold": [1e-8],

    "mf_acq_noise": [False],
    "acq_noise": [True],
    "use_power": True,
    "power_beta": [2],
    "sparse_sim_matrix": True,
    "mean_field_beta": [3],
    "info_gain_lambda": 1,
    "num_edges_info_gain": [20],
    "info_gain_pair_mode": ["entropy"],

    "dataset_name": "synthetic",
    "dataset_n_samples": 500,
    "dataset_n_clusters": [10],
    "dataset_class_balance": None,
    "dataset_class_sep": [1.5],
    "dataset_n_features": [10],
    "dataset_y_flip": [0],
}

start_index = er.generate_experiments(
    folder="../configs/ablation",
    options_to_keep=[],
    start_index=start_index, 
    **config
)

# %% [markdown]
# # runtime

# %%
config = {
    "_experiment_name": "ablation3",
    "_num_repeats": 14,
    "_n_workers": 14,
    "_local": True,
    "_verbose": True,
    "_overwrite": False,
    "_mode": "ac",

    "seed": 14,
    "batch_size": [0.0025],
    "noise_level": [0.4],
    "clustering_alg": "CC",
    "warm_start": [0.01],
    "K_init": 10,
    "sim_init": [0.01],
    "sim_init_type": ["zeros"],
    "sample_size": 1,
    "infer_threshold": [-1],
    "start_inferring": [0],

    "acq_fn": ["unif", "maxmin", "maxexp", "entropy", "info_gain_pairs_random", "info_gain_object", "info_gain_pairs"],

    "eps": [0.8],
    "beta": [1],
    "tau": [3],
    "num_maxmin_edges": -1,

    "alpha1": [1],
    "alpha2": [0.5],
    "alpha3": [1],

    "r": [0.02],
    "num_mc_samples": [5],
    "num_mc": [50],

    "num_mc_mf": [1],
    "mf_noise": [0],
    "reinit": [False],
    "mf_iterations": [200],
    "conv_threshold": [1e-8],

    "mf_acq_noise": [False],
    "acq_noise": [True],
    "use_power": True,
    "power_beta": [2],
    "sparse_sim_matrix": True,
    "mean_field_beta": [3],
    "info_gain_lambda": 1,
    "num_edges_info_gain": [20],
    "info_gain_pair_mode": ["entropy"],

    "dataset_name": "synthetic",
    "dataset_n_samples": 500,
    "dataset_n_clusters": [10],
    "dataset_class_balance": None,
    "dataset_class_sep": [1.5],
    "dataset_n_features": [10],
    "dataset_y_flip": [0],
}

start_index = er.generate_experiments(
    folder="../configs/ablation",
    options_to_keep=[],
    start_index=start_index, 
    **config
)

# %% [markdown]
# # EIG ablation

# %%
start_index = 1
config = {
    "_experiment_name": "ablation4",
    "_num_repeats": 14,
    "_n_workers": 14,
    "_local": True,
    "_verbose": True,
    "_overwrite": False,
    "_mode": "ac",

    "seed": 14,
    "batch_size": [0.0025],
    "noise_level": [0.4],
    "clustering_alg": "CC",
    "warm_start": [0.01],
    "K_init": 10,
    "sim_init": [0.01],
    "sim_init_type": ["zeros"],
    "sample_size": 1,
    "infer_threshold": [-1],
    "start_inferring": [0],

    "acq_fn": ["info_gain_object"],

    "eps": [0.8],
    "beta": [1],
    "tau": [3],
    "num_maxmin_edges": -1,

    "alpha1": [1],
    "alpha2": [0.5],
    "alpha3": [1],

    "r": [0.02],
    "num_mc_samples": [5],
    "num_mc": [50],

    "num_mc_mf": [1],
    "mf_noise": [0],
    "reinit": [False],
    "mf_iterations": [200],
    "conv_threshold": [1e-8],

    "mf_acq_noise": [False],
    "acq_noise": [True],
    "use_power": True,
    "power_beta": [1, 2],
    "sparse_sim_matrix": True,
    "mean_field_beta": [3],
    "info_gain_lambda": 1,
    "num_edges_info_gain": [1, 3, 5, 10, 20, 50],
    "info_gain_pair_mode": ["entropy"],

    "dataset_name": "synthetic",
    "dataset_n_samples": 500,
    "dataset_n_clusters": [10],
    "dataset_class_balance": None,
    "dataset_class_sep": [1.5],
    "dataset_n_features": [10],
    "dataset_y_flip": [0],
}

start_index = er.generate_experiments(
    folder="../configs/ablation",
    options_to_keep=[],
    start_index=start_index, 
    **config
)

# %% [markdown]
# # JEIG ablation

# %%
config = {
    "_experiment_name": "ablation5",
    "_num_repeats": 14,
    "_n_workers": 14,
    "_local": True,
    "_verbose": True,
    "_overwrite": False,
    "_mode": "ac",

    "seed": 14,
    "batch_size": [0.0025],
    "noise_level": [0.4],
    "clustering_alg": "CC",
    "warm_start": [0.01],
    "K_init": 10,
    "sim_init": [0.01],
    "sim_init_type": ["zeros"],
    "sample_size": 1,
    "infer_threshold": [-1],
    "start_inferring": [0],

    "acq_fn": ["info_gain_pairs_random"],

    "eps": [0.8],
    "beta": [1],
    "tau": [3],
    "num_maxmin_edges": -1,

    "alpha1": [1],
    "alpha2": [0.5],
    "alpha3": [1],

    "r": [0.002, 0.02, 0.2],
    "num_mc_samples": [1, 5],
    "num_mc": [1, 10, 50],

    "num_mc_mf": [1],
    "mf_noise": [0],
    "reinit": [False],
    "mf_iterations": [200],
    "conv_threshold": [1e-8],

    "mf_acq_noise": [False],
    "acq_noise": [True],
    "use_power": True,
    "power_beta": [1, 2],
    "sparse_sim_matrix": True,
    "mean_field_beta": [3],
    "info_gain_lambda": 1,
    "num_edges_info_gain": [20],
    "info_gain_pair_mode": ["entropy"],

    "dataset_name": "synthetic",
    "dataset_n_samples": 500,
    "dataset_n_clusters": [10],
    "dataset_class_balance": None,
    "dataset_class_sep": [1.5],
    "dataset_n_features": [10],
    "dataset_y_flip": [0],
}

start_index = er.generate_experiments(
    folder="../configs/ablation",
    options_to_keep=[],
    start_index=start_index, 
    **config
)

# %% [markdown]
# # small batch size

# %%
config = {
    "_experiment_name": "ablation6",
    "_num_repeats": 14,
    "_n_workers": 14,
    "_local": True,
    "_verbose": True,
    "_overwrite": False,
    "_mode": "ac",

    "seed": 14,
    "batch_size": [5],
    "noise_level": [0.4],
    "clustering_alg": "CC",
    "warm_start": [0.01],
    "K_init": 10,
    "sim_init": [0.01],
    "sim_init_type": ["zeros"],
    "sample_size": 1,
    "infer_threshold": [-1],
    "start_inferring": [0],

    "acq_fn": ["unif", "entropy", "info_gain_pairs_random", "info_gain_object", "info_gain_pairs"],

    "eps": [0.8],
    "beta": [1],
    "tau": [3],
    "num_maxmin_edges": -1,

    "alpha1": [1],
    "alpha2": [0.5],
    "alpha3": [1],

    "r": [0.02],
    "num_mc_samples": [5],
    "num_mc": [50],

    "num_mc_mf": [1],
    "mf_noise": [0],
    "reinit": [False],
    "mf_iterations": [200],
    "conv_threshold": [1e-8],

    "mf_acq_noise": [False],
    "acq_noise": [True, False],
    "use_power": True,
    "power_beta": [1],
    "sparse_sim_matrix": True,
    "mean_field_beta": [3],
    "info_gain_lambda": 1,
    "num_edges_info_gain": [-1],
    "info_gain_pair_mode": ["entropy"],

    "dataset_name": "synthetic",
    "dataset_n_samples": 70,
    "dataset_n_clusters": [5],
    "dataset_class_balance": None,
    "dataset_class_sep": [1.5],
    "dataset_n_features": [10],
    "dataset_y_flip": [0],
}

start_index = er.generate_experiments(
    folder="../configs/ablation",
    options_to_keep=[],
    start_index=start_index, 
    **config
)

# %%
from rac.experiment_data import ExperimentReader
er = ExperimentReader(metrics=["rand", "num_repeat_queries", "num_violations", "time_select_batch"])
data = er.read_all_data(folder="../experiment_results_local/ablation1")


config = {
    "_experiment_name": "ablation1",
    "_num_repeats": 14,
    "_n_workers": 14,
    "_local": True,
    "_verbose": True,
    "_overwrite": False,
    "_mode": "ac",

    "seed": 14,
    "batch_size": [100, 500, 1000, 2000],
    "noise_level": [0.4],
    "clustering_alg": "CC",
    "warm_start": [0.01],
    "K_init": 10,
    "sim_init": [0.01],
    "sim_init_type": ["zeros"],
    "sample_size": 1,
    "infer_threshold": [-1],
    "start_inferring": [0],

    "acq_fn": ["unif", "maxmin", "maxexp", "entropy", "info_gain_pairs_random", "info_gain_object", "info_gain_pairs"],

    "eps": [0.8],
    "beta": [1],
    "tau": [3],
    "num_maxmin_edges": -1,

    "alpha1": [1],
    "alpha2": [0.5],
    "alpha3": [1],

    "r": [0.02],
    "num_mc_samples": [5],
    "num_mc": [50],

    "num_mc_mf": [1],
    "mf_noise": [0],
    "reinit": [False],
    "mf_iterations": [200],
    "conv_threshold": [1e-8],

    "mf_acq_noise": [False],
    "acq_noise": [True],
    "use_power": True,
    "power_beta": [2],
    "sparse_sim_matrix": True,
    "mean_field_beta": [3],
    "info_gain_lambda": 1,
    "num_edges_info_gain": [20],
    "info_gain_pair_mode": ["entropy"],

    "dataset_name": "synthetic",
    "dataset_n_samples": 500,
    "dataset_n_clusters": [10],
    "dataset_class_balance": None,
    "dataset_class_sep": [1.5],
    "dataset_n_features": [10],
    "dataset_y_flip": [0],
}

er.generate_AL_curves(
    data,
    save_location="../plots/test_experiment258/",
    categorize=[],
    compare=["acq_fn"],
    vary=["x"],
    options_in_file_name=["noise_level", "batch_size"],
    auc=True,
    summary_method="auc_max_ind",
    indices=[], 
    threshold=1,
    err_style="band",
    marker="o",
    markersize=6,
    capsize=6,
    linestyle="solid",
    prop=False,
    **config
)
# Out:
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:483: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:483: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:483: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:483: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:483: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:483: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:483: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:483: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:483: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:483: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:483: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:483: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:483: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:483: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:483: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:483: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)

# %%
from rac.experiment_data import ExperimentReader
er = ExperimentReader(metrics=["rand", "num_repeat_queries", "num_violations", "time_select_batch"])
data = er.read_all_data(folder="../experiment_results_local/ablation4")
config = {
    "_experiment_name": "ablation4",
    "_num_repeats": 14,
    "_n_workers": 14,
    "_local": True,
    "_verbose": True,
    "_overwrite": False,
    "_mode": "ac",

    "seed": 14,
    "batch_size": [0.0025],
    "noise_level": [0.4],
    "clustering_alg": "CC",
    "warm_start": [0.01],
    "K_init": 10,
    "sim_init": [0.01],
    "sim_init_type": ["zeros"],
    "sample_size": 1,
    "infer_threshold": [-1],
    "start_inferring": [0],

    "acq_fn": ["info_gain_object", "info_gain_pairs"],

    "eps": [0.8],
    "beta": [1],
    "tau": [3],
    "num_maxmin_edges": -1,

    "alpha1": [1],
    "alpha2": [0.5],
    "alpha3": [1],

    "r": [0.02],
    "num_mc_samples": [5],
    "num_mc": [50],

    "num_mc_mf": [1],
    "mf_noise": [0],
    "reinit": [False],
    "mf_iterations": [200],
    "conv_threshold": [1e-8],

    "mf_acq_noise": [False],
    "acq_noise": [True],
    "use_power": True,
    "power_beta": [1, 2],
    "sparse_sim_matrix": True,
    "mean_field_beta": [3],
    "info_gain_lambda": 1,
    "num_edges_info_gain": [1, 3, 5, 10, 20, 50],
    "info_gain_pair_mode": ["entropy"],

    "dataset_name": "synthetic",
    "dataset_n_samples": 500,
    "dataset_n_clusters": [10],
    "dataset_class_balance": None,
    "dataset_class_sep": [1.5],
    "dataset_n_features": [10],
    "dataset_y_flip": [0],
}

er.generate_AL_curves2(
    data,
    save_location="../plots/test_experiment257/",
    categorize=[],
    compare=["acq_fn", "num_edges_info_gain"],
    vary=["x"],
    options_in_file_name=["noise_level"],
    auc=True,
    summary_method="auc_max_ind",
    indices=[], 
    threshold=1,
    err_style="band",
    marker="o",
    markersize=6,
    capsize=6,
    linestyle="solid",
    prop=False,
    **config
)
# Out:
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:731: UserWarning: The palette list has more values (36) than needed (4), which may not be intended.
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:775: UserWarning: FixedFormatter should only be used together with FixedLocator
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:731: UserWarning: The palette list has more values (36) than needed (4), which may not be intended.
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:775: UserWarning: FixedFormatter should only be used together with FixedLocator
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:731: UserWarning: The palette list has more values (36) than needed (4), which may not be intended.
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:775: UserWarning: FixedFormatter should only be used together with FixedLocator
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:731: UserWarning: The palette list has more values (36) than needed (4), which may not be intended.
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:775: UserWarning: FixedFormatter should only be used together with FixedLocator
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:731: UserWarning: The palette list has more values (36) than needed (3), which may not be intended.
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:775: UserWarning: FixedFormatter should only be used together with FixedLocator
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:731: UserWarning: The palette list has more values (36) than needed (3), which may not be intended.
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:775: UserWarning: FixedFormatter should only be used together with FixedLocator
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:731: UserWarning: The palette list has more values (36) than needed (3), which may not be intended.
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:775: UserWarning: FixedFormatter should only be used together with FixedLocator
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:731: UserWarning: The palette list has more values (36) than needed (3), which may not be intended.
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:775: UserWarning: FixedFormatter should only be used together with FixedLocator
