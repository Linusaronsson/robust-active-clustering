# %%
start_index = 1
from rac.experiment_data import ExperimentReader
exp_reader = ExperimentReader()
config = {
    "general_options": {
        "experiment_name": "infer_exp",
        "num_repeats": 10,
        "n_workers": 60,
        "local": True,
        "verbose": False
    },
    "experiment_options": {
        "seed": 33,
        "num_feedback": 0.001,
        "noise_level": [0.0, 0.2, 0.4],
        "persistent_noise_level": 0.0,
        "force_global_update": True,
        "save_matrix_data": False,
        "infer_sims": False,
        "infer_sims2": [True],
        "infer_sims3": [False]
    },
    "sim_init_options": {
        "K_init": 10,
        "sim_init": 0.1,
        "sim_init_type": "custom",
        "init_noise_level": 0.2
    },
    "query_strategy_options": {
        "acq_fn": ["freq"],
        "local_regions": "pairs",
        "eps": [0.3],
        "beta": 1,
        "tau": [7],
        "alpha": 1
    },
    "dataset_options": {
        "dataset": "synthetic",
        "n_samples": 500,
        "n_clusters": 10,
        "class_balance": None
    }
}

start_index = exp_reader.generate_experiments(
    folder="../configs/infer_exp/", 
    options_to_keep=["eps", "noise_level"],
    start_index=start_index,
    **config
)

# %%
from rac.experiment_data import ExperimentReader
exp_reader = ExperimentReader()
config = {
    "general_options": {
        "experiment_name": "infer_exp",
        "num_repeats": 10,
        "n_workers": 60,
        "local": True,
        "verbose": False
    },
    "experiment_options": {
        "seed": 33,
        "num_feedback": 0.001,
        "noise_level": [0.0, 0.2, 0.4],
        "persistent_noise_level": 0.0,
        "force_global_update": True,
        "save_matrix_data": False,
        "infer_sims": False,
        "infer_sims2": [False],
        "infer_sims3": [False, True]
    },
    "sim_init_options": {
        "K_init": 10,
        "sim_init": 0.1,
        "sim_init_type": "custom",
        "init_noise_level": 0.2
    },
    "query_strategy_options": {
        "acq_fn": ["freq"],
        "local_regions": "pairs",
        "eps": [0.3],
        "beta": 1,
        "tau": [7],
        "alpha": 1
    },
    "dataset_options": {
        "dataset": "synthetic",
        "n_samples": 500,
        "n_clusters": 10,
        "class_balance": None
    }
}

start_index = exp_reader.generate_experiments(
    folder="../configs/infer_exp/", 
    options_to_keep=["eps", "noise_level"],
    start_index=start_index,
    **config
)

# %%
from rac.experiment_data import ExperimentReader
metrics = ["rand", "ami"]
ac = ExperimentReader(metrics=metrics)

config = {
    "general_options": {
        "experiment_name": "infer_exp",
        "num_repeats": 10,
        "n_workers": 60,
        "local": True,
        "verbose": False
    },
    "experiment_options": {
        "seed": 33,
        "num_feedback": 0.001,
        "noise_level": [0.0, 0.2, 0.4],
        "persistent_noise_level": 0.0,
        "force_global_update": True,
        "save_matrix_data": False,
        "infer_sims": False,
        "infer_sims2": [False, True],
        "infer_sims3": [False, True]
    },
    "sim_init_options": {
        "K_init": 10,
        "sim_init": 0.1,
        "sim_init_type": "custom"
        "init_noise_level": 0.2
    },
    "query_strategy_options": {
        "acq_fn": ["freq"],
        "local_regions": ["pairs"],
        "eps": [0.3],
        "beta": 1,
        "tau": [7],
        "alpha": 1
    },
    "dataset_options": {
        "dataset": "synthetic",
        "n_samples": 500,
        "n_clusters": 10,
        "class_balance": None
    }
}
data = ac.read_all_data(folder="../experiment_results_local/infer_exp")
ac.generate_AL_curves(
    data,
    save_location="../plots/infer_plots",
    categorize=["dataset"],
    compare=["acq_fn", "local_regions", "infer_sims2", "infer_sims3"], 
    vary=["x"],
    auc=True,
    summary_method="auc_max_ind",
    indices=[], 
    threshold=1,
    err_style="band",
    marker="o",
    markersize=6,
    capsize=6,
    linestyle="solid",
    **config
)
# Out:
# no data found in folder
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /home/linaro/github_projects/robust-active-clustering/notebooks/inferring.ipynb Cell 4 in <cell line: 45>()
#       <a href='vscode-notebook-cell:/home/linaro/github_projects/robust-active-clustering/notebooks/inferring.ipynb#W5sZmlsZQ%3D%3D?line=4'>5</a> config = {
#       <a href='vscode-notebook-cell:/home/linaro/github_projects/robust-active-clustering/notebooks/inferring.ipynb#W5sZmlsZQ%3D%3D?line=5'>6</a>     "general_options": {
#       <a href='vscode-notebook-cell:/home/linaro/github_projects/robust-active-clustering/notebooks/inferring.ipynb#W5sZmlsZQ%3D%3D?line=6'>7</a>         "experiment_name": "infer_exp",
#    (...)
#      <a href='vscode-notebook-cell:/home/linaro/github_projects/robust-active-clustering/notebooks/inferring.ipynb#W5sZmlsZQ%3D%3D?line=41'>42</a>     }
#      <a href='vscode-notebook-cell:/home/linaro/github_projects/robust-active-clustering/notebooks/inferring.ipynb#W5sZmlsZQ%3D%3D?line=42'>43</a> }
#      <a href='vscode-notebook-cell:/home/linaro/github_projects/robust-active-clustering/notebooks/inferring.ipynb#W5sZmlsZQ%3D%3D?line=43'>44</a> data = ac.read_all_data(folder="../experiment_results_local/infer_exp")
# ---> <a href='vscode-notebook-cell:/home/linaro/github_projects/robust-active-clustering/notebooks/inferring.ipynb#W5sZmlsZQ%3D%3D?line=44'>45</a> ac.generate_AL_curves(
#      <a href='vscode-notebook-cell:/home/linaro/github_projects/robust-active-clustering/notebooks/inferring.ipynb#W5sZmlsZQ%3D%3D?line=45'>46</a>     data,
#      <a href='vscode-notebook-cell:/home/linaro/github_projects/robust-active-clustering/notebooks/inferring.ipynb#W5sZmlsZQ%3D%3D?line=46'>47</a>     save_location="../plots/infer_plots",
#      <a href='vscode-notebook-cell:/home/linaro/github_projects/robust-active-clustering/notebooks/inferring.ipynb#W5sZmlsZQ%3D%3D?line=47'>48</a>     categorize=["dataset", "noise_level"],
#      <a href='vscode-notebook-cell:/home/linaro/github_projects/robust-active-clustering/notebooks/inferring.ipynb#W5sZmlsZQ%3D%3D?line=48'>49</a>     compare=["acq_fn", "local_regions", "infer_sims2", "infer_sims3"],
#      <a href='vscode-notebook-cell:/home/linaro/github_projects/robust-active-clustering/notebooks/inferring.ipynb#W5sZmlsZQ%3D%3D?line=49'>50</a>     vary=["x"],
#      <a href='vscode-notebook-cell:/home/linaro/github_projects/robust-active-clustering/notebooks/inferring.ipynb#W5sZmlsZQ%3D%3D?line=50'>51</a>     auc=True,
#      <a href='vscode-notebook-cell:/home/linaro/github_projects/robust-active-clustering/notebooks/inferring.ipynb#W5sZmlsZQ%3D%3D?line=51'>52</a>     summary_method="auc_max_ind",
#      <a href='vscode-notebook-cell:/home/linaro/github_projects/robust-active-clustering/notebooks/inferring.ipynb#W5sZmlsZQ%3D%3D?line=52'>53</a>     indices=[],
#      <a href='vscode-notebook-cell:/home/linaro/github_projects/robust-active-clustering/notebooks/inferring.ipynb#W5sZmlsZQ%3D%3D?line=53'>54</a>     threshold=1,
#      <a href='vscode-notebook-cell:/home/linaro/github_projects/robust-active-clustering/notebooks/inferring.ipynb#W5sZmlsZQ%3D%3D?line=54'>55</a>     err_style="band",
#      <a href='vscode-notebook-cell:/home/linaro/github_projects/robust-active-clustering/notebooks/inferring.ipynb#W5sZmlsZQ%3D%3D?line=55'>56</a>     marker="o",
#      <a href='vscode-notebook-cell:/home/linaro/github_projects/robust-active-clustering/notebooks/inferring.ipynb#W5sZmlsZQ%3D%3D?line=56'>57</a>     markersize=6,
#      <a href='vscode-notebook-cell:/home/linaro/github_projects/robust-active-clustering/notebooks/inferring.ipynb#W5sZmlsZQ%3D%3D?line=57'>58</a>     capsize=6,
#      <a href='vscode-notebook-cell:/home/linaro/github_projects/robust-active-clustering/notebooks/inferring.ipynb#W5sZmlsZQ%3D%3D?line=58'>59</a>     linestyle="solid",
#      <a href='vscode-notebook-cell:/home/linaro/github_projects/robust-active-clustering/notebooks/inferring.ipynb#W5sZmlsZQ%3D%3D?line=59'>60</a>     **config
#      <a href='vscode-notebook-cell:/home/linaro/github_projects/robust-active-clustering/notebooks/inferring.ipynb#W5sZmlsZQ%3D%3D?line=60'>61</a> )
#
# File ~/github_projects/robust-active-clustering/rac/experiment_data.py:319, in ExperimentReader.generate_AL_curves(self, data, save_location, categorize, compare, vary, auc, summary_method, indices, threshold, err_style, marker, markersize, capsize, linestyle, **config)
#     317 for metric in self.metrics:
#     318     col = "mean_" + metric
# --> 319     data[col] = data[metric].apply(lambda x: np.mean(x, axis=0)) # axis 1 since we transpose in read_all_data (i.e., shape is (num_iterations, num_repeats))
#     320     data['array_lengths'] = data[col].apply(lambda x: len(x))
#     321     max_length = data['array_lengths'].max()
#
# TypeError: 'NoneType' object is not subscriptable
