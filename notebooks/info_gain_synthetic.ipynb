# %%
from rac.experiment_data import ExperimentReader
exp_reader = ExperimentReader(["rand"])

start_index = 1
config = {
    "general_options": {
        "experiment_name": "info_gain_exp_synthetic",
        "num_repeats": 14,
        "n_workers": 14,
        "local": True,
        "verbose": False
    },
    "experiment_options": {
        "seed": 13,
        "num_feedback": 0.01,
        "noise_level": [0.4, 0.6],
        "persistent_noise_level": 0.0,
        "save_matrix_data": False,
        "infer_sims": False,
        "predict_sims": False,
        "clustering_alg": "CC",
        "warm_start": [0, 0.005, 0.01, 0.02, 0.05]
    },

    "sim_init_options": {
        "K_init": 10,
        "sim_init": [0.01],
        "sim_init_type": ["zeros"]
    },
    "query_strategy_options": {
        "acq_fn": ["freq", "entropy", "info_gain_object", "cluster_incon", "maxexp", "maxmin"],
        "eps": 0.3,
        "beta": 8,
        "tau": [7],
        "alpha": [1],
        "num_maxmin_edges": -1,

        "use_power": [True],
        "use_grumbel": [True, False],
        "power_beta": [1],
        "sparse_sim_matrix": [True],
        "mean_field_beta": [20],
        "info_gain_lambda": [20],
        "running_avg": True,
        "num_edges_info_gain": [50],
        "U_size": [1],
        "G_size": [1],
        "info_gain_object_mode": ["uniform"],
        "info_gain_pair_mode": ["uniform", "entropy"],
        "mf_iterations": [50],
    },
    "dataset_options": {
        "dataset": "synthetic",
        "n_samples": 500,
        "n_clusters": 10,
        "class_balance": None
    }
}


start_index = exp_reader.generate_experiments(
    folder="../configs/info_gain_exp_synthetic/", 
    options_to_keep=[],
    start_index=start_index,
    **config
)

# %%
from rac.experiment_data import ExperimentReader
exp_reader = ExperimentReader(["rand"])

config = {
    "general_options": {
        "experiment_name": "info_gain_exp_synthetic",
        "num_repeats": 14,
        "n_workers": 14,
        "local": True,
        "verbose": False
    },
    "experiment_options": {
        "seed": 13,
        "num_feedback": [10, 50, 100, 500, 1000, 2000, 4000, 8000],
        "noise_level": [0.4],
        "persistent_noise_level": 0.0,
        "save_matrix_data": False,
        "infer_sims": False,
        "predict_sims": False,
        "clustering_alg": "CC",
        "warm_start": [0, 0.01, 0.02]
    },

    "sim_init_options": {
        "K_init": 10,
        "sim_init": [0.01],
        "sim_init_type": ["zeros"]
    },
    "query_strategy_options": {
        "acq_fn": ["freq", "entropy", "info_gain_object", "cluster_incon", "maxexp", "maxmin"],
        "eps": 0.3,
        "beta": 8,
        "tau": [7],
        "alpha": [1],
        "num_maxmin_edges": -1,

        "use_power": [True],
        "use_grumbel": [True],
        "power_beta": [1],
        "sparse_sim_matrix": [True],
        "mean_field_beta": [20],
        "info_gain_lambda": [20],
        "running_avg": True,
        "num_edges_info_gain": [50],
        "U_size": [1],
        "G_size": [1],
        "info_gain_object_mode": ["uniform"],
        "info_gain_pair_mode": ["uniform"],
        "mf_iterations": [50],
    },
    "dataset_options": {
        "dataset": "synthetic",
        "n_samples": 500,
        "n_clusters": 10,
        "class_balance": None
    }
}


start_index = exp_reader.generate_experiments(
    folder="../configs/info_gain_exp_synthetic/", 
    options_to_keep=[],
    start_index=start_index,
    **config
)

# %%
from rac.experiment_data import ExperimentReader
exp_reader = ExperimentReader(["rand"])

config = {
    "general_options": {
        "experiment_name": "info_gain_exp_synthetic",
        "num_repeats": 14,
        "n_workers": 14,
        "local": True,
        "verbose": False
    },
    "experiment_options": {
        "seed": 13,
        "num_feedback": 0.01,
        "noise_level": [0, 0.2, 0.4, 0.6, 0.8],
        "persistent_noise_level": 0.0,
        "save_matrix_data": False,
        "infer_sims": False,
        "predict_sims": False,
        "clustering_alg": "CC",
        "warm_start": [0, 0.01, 0.02]
    },

    "sim_init_options": {
        "K_init": 10,
        "sim_init": [0.01],
        "sim_init_type": ["zeros"]
    },
    "query_strategy_options": {
        "acq_fn": ["freq", "entropy", "info_gain_object", "cluster_incon", "maxexp", "maxmin"],
        "eps": 0.3,
        "beta": 8,
        "tau": [7],
        "alpha": [1],
        "num_maxmin_edges": -1,

        "use_power": [True],
        "use_grumbel": [True],
        "power_beta": [1],
        "sparse_sim_matrix": [True],
        "mean_field_beta": [20],
        "info_gain_lambda": [20],
        "running_avg": True,
        "num_edges_info_gain": [50],
        "U_size": [1],
        "G_size": [1],
        "info_gain_object_mode": ["uniform"],
        "info_gain_pair_mode": ["uniform"],
        "mf_iterations": [50],
    },
    "dataset_options": {
        "dataset": "synthetic",
        "n_samples": 500,
        "n_clusters": 10,
        "class_balance": None
    }
}


start_index = exp_reader.generate_experiments(
    folder="../configs/info_gain_exp_synthetic/", 
    options_to_keep=[],
    start_index=start_index,
    **config
)

# %%
from rac.experiment_data import ExperimentReader
metrics = ["rand", "ami"]
ac = ExperimentReader(metrics=metrics)

config = {
    "general_options": {
        "experiment_name": "info_gain_exp_synthetic",
        "num_repeats": 14,
        "n_workers": 14,
        "local": True,
        "verbose": False
    },
    "experiment_options": {
        "seed": 13,
        "num_feedback": [10, 50, 100, 500, 1000, 2000, 4000, 8000],
        "noise_level": [0.4],
        "persistent_noise_level": 0.0,
        "save_matrix_data": False,
        "infer_sims": False,
        "predict_sims": False,
        "clustering_alg": "CC",
        "warm_start": [0, 0.01, 0.02]
    },

    "sim_init_options": {
        "K_init": 10,
        "sim_init": [0.01],
        "sim_init_type": ["zeros"]
    },
    "query_strategy_options": {
        "acq_fn": ["freq", "entropy", "info_gain_object", "cluster_incon", "maxexp", "maxmin"],
        "eps": 0.3,
        "beta": 8,
        "tau": [7],
        "alpha": [1],
        "num_maxmin_edges": -1,

        "use_power": [True],
        "use_grumbel": [True],
        "power_beta": [1],
        "sparse_sim_matrix": [True],
        "mean_field_beta": [20],
        "info_gain_lambda": [20],
        "running_avg": True,
        "num_edges_info_gain": [50],
        "U_size": [1],
        "G_size": [1],
        "info_gain_object_mode": ["uniform"],
        "info_gain_pair_mode": ["uniform"],
        "mf_iterations": [50],
    },
    "dataset_options": {
        "dataset": "synthetic",
        "n_samples": 500,
        "n_clusters": 10,
        "class_balance": None
    }
}


data = ac.read_all_data(folder="../experiment_results_local/info_gain_exp_synthetic")

ac.generate_AL_curves2(
    data,
    save_location="../plots/info_gain_synthetic/batch_size/",
    categorize=["noise_level", "warm_start", "info_gain_pair_mode"],
    compare=["acq_fn"], 
    vary=["num_feedback"],
    auc=True,
    summary_method="batch_size",
    indices=[], 
    threshold=1,
    err_style="bars",
    marker="o",
    markersize=6,
    capsize=6,
    linestyle="solid",
    **config
)
# Out:
# EOF error in read data
# ---------------------------------------------------------------------------
# UnpicklingError                           Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7328\1953676739.py in <module>
#      59
#      60
# ---> 61 data = ac.read_all_data(folder="../experiment_results_local/info_gain_exp_synthetic")
#      62
#      63 ac.generate_AL_curves2(
#
# c:\github_projects\robust-active-clustering\rac\experiment_data.py in read_all_data(self, folder)
#     135                 with open(path + "/" + name, 'rb') as handle:
#     136                     try:
# --> 137                         exp = pickle.load(handle)
#     138                     except EOFError:
#     139                         print("EOF error in read data")
#
# UnpicklingError: invalid load key, '\x00'.

# %%
from rac.experiment_data import ExperimentReader
metrics = ["rand", "ami"]
ac = ExperimentReader(metrics=metrics)

datasets = ["20newsgroups", "cifar10", "mnist", "cardiotocography", "yeast", "breast_cancer", "ecoli", "forest_type_mapping", "mushrooms", "user_knowledge"]

config = {
    "general_options": {
        "experiment_name": "info_gain_exp",
        "num_repeats": 14,
        "n_workers": 14,
        "local": True,
        "verbose": False
    },
    "experiment_options": {
        "seed": 13,
        "num_feedback": 0.01,
        "noise_level": [0.4],
        "persistent_noise_level": 0.0,
        "save_matrix_data": False,
        "infer_sims": False,
        "predict_sims": False,
        "clustering_alg": "CC",
        "warm_start": [0, 0.005, 0.01, 0.02, 0.05]
    },

    "sim_init_options": {
        "K_init": 10,
        "sim_init": [0.01],
        "sim_init_type": ["zeros"]
    },
    "query_strategy_options": {
        "acq_fn": ["freq", "entropy", "info_gain_object", "cluster_incon", "maxexp"],
        "eps": 0.3,
        "beta": 8,
        "tau": [7],
        "alpha": [1],
        "num_maxmin_edges": -1,

        "use_power": [True],
        "use_grumbel": [True],
        "power_beta": [1],
        "sparse_sim_matrix": [True],
        "mean_field_beta": [20],
        "info_gain_lambda": [20],
        "running_avg": True,
        "num_edges_info_gain": [50],
        "U_size": [1],
        "G_size": [1],
        "info_gain_object_mode": ["uniform"],
        "info_gain_pair_mode": ["uniform"],
        "mf_iterations": [50],
    },
    "dataset_options": {
        "dataset": datasets
    }
}

data = ac.read_all_data(folder="../experiment_results_local/info_gain_exp/")
ac.generate_AL_curves(
    data,
    save_location="../plots/info_gain_exp/",
    categorize=[],
    compare=["acq_fn"],
    vary=["x"],
    auc=True,
    summary_method="auc_max_ind",
    indices=[], 
    threshold=1,
    err_style="band",
    marker="o",
    markersize=6,
    capsize=6,
    linestyle="solid",
    **config)
