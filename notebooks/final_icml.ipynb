# %%
from rac.experiment_data import ExperimentReader
exp_reader = ExperimentReader(["rand"])

start_index = 1
config = {
    "general_options": {
        "experiment_name": "final_icml",
        "num_repeats": 14,
        "n_workers": 14,
        "local": True,
        "verbose": False
    },
    "experiment_options": {
        "seed": 13,
        "num_feedback": 0.01,
        "noise_level": [0.2, 0.4, 0.6],
        "persistent_noise_level": 0.0,
        "save_matrix_data": False,
        "infer_sims": False,
        "predict_sims": False,
        "clustering_alg": "CC",
        "warm_start": [0, 0.01]
    },

    "sim_init_options": {
        "K_init": 10,
        "sim_init": [0.0001, 0.01, 0.1],
        "sim_init_type": ["uniform_random", "custom"]
    },
    "query_strategy_options": {
        "acq_fn": ["freq", "entropy", "cluster_incon", "maxexp", "maxmin"],
        "eps": 0.3,
        "beta": [1],
        "tau": [7],
        "alpha": [0.2, 0.5, 0.7, 1],
        "num_maxmin_edges": -1,

        "use_power": [True],
        "use_grumbel": [True],
        "power_beta": [1],
        "sparse_sim_matrix": [True],
        "mean_field_beta": [3],
        "info_gain_lambda": [1],
        "running_avg": True,
        "num_edges_info_gain": [50],
        "U_size": [1],
        "G_size": [1],
        "info_gain_object_mode": ["uniform"],
        "info_gain_pair_mode": ["uniform"],
        "mf_iterations": [50],
    },
    "dataset_options": {
        "dataset": "synthetic",
        "n_samples": 500,
        "n_clusters": 10,
        "class_balance": None
    }
}



start_index = exp_reader.generate_experiments(
    folder="../configs/info_gain_exp_synthetic_gg/", 
    options_to_keep=[],
    start_index=start_index,
    **config
)
