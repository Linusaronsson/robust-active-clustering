# %%
from rac.experiment_data import ExperimentReader
exp_reader = ExperimentReader(["rand"])

start_index = 1
config = {
    "general_options": {
        "experiment_name": "final_icml2",
        "num_repeats": 14,
        "n_workers": 14,
        "local": True,
        "verbose": False
    },
    "experiment_options": {
        "seed": 13,
        "num_feedback": 0.01,
        "noise_level": [0.2, 0.4, 0.6],
        "persistent_noise_level": 0.0,
        "save_matrix_data": False,
        "infer_sims": False,
        "predict_sims": False,
        "clustering_alg": "CC",
        "warm_start": [0, 0.01, 0.02]
    },

    "sim_init_options": {
        "K_init": 10,
        "sim_init": [0.0001, 0.01, 0.1],
        "sim_init_type": ["custom"]
    },
    "query_strategy_options": {
        "acq_fn": ["freq", "entropy", "cluster_incon", "maxexp", "maxmin"],
        "eps": [0, 0.1, 0.3],
        "beta": [1],
        "tau": [7],
        "alpha": [0, 0.2, 0.5, 0.7, 1],
        "num_maxmin_edges": -1,

        "use_power": [True],
        "use_grumbel": [True],
        "power_beta": [1],
        "sparse_sim_matrix": [True],
        "mean_field_beta": [3],
        "info_gain_lambda": [1],
        "running_avg": True,
        "num_edges_info_gain": [50],
        "U_size": [1],
        "G_size": [1],
        "info_gain_object_mode": ["uniform"],
        "info_gain_pair_mode": ["uniform"],
        "mf_iterations": [50],
    },
    "dataset_options": {
        "dataset": "synthetic",
        "n_samples": 500,
        "n_clusters": 10,
        "class_balance": None
    }
}



start_index = exp_reader.generate_experiments(
    folder="../configs/final_icml2/", 
    options_to_keep=[],
    start_index=start_index,
    **config
)

# %%
from rac.experiment_data import ExperimentReader
exp_reader = ExperimentReader(["rand"])

start_index = 1
config = {
    "general_options": {
        "experiment_name": "final_icml2",
        "num_repeats": 14,
        "n_workers": 14,
        "local": True,
        "verbose": False
    },
    "experiment_options": {
        "seed": 13,
        "num_feedback": [0.01, 0.005],
        "noise_level": [0.4, 0.6],
        "persistent_noise_level": 0.0,
        "save_matrix_data": False,
        "infer_sims": False,
        "predict_sims": False,
        "clustering_alg": "CC",
        "warm_start": [0, 0.02]
    },

    "sim_init_options": {
        "K_init": 10,
        "sim_init": [0.01],
        "sim_init_type": ["custom"]
    },
    "query_strategy_options": {
        "acq_fn": ["entropy", "cluster_incon", "maxexp", "maxmin"],
        "eps": [0.3],
        "beta": [1],
        "tau": [7],
        "alpha": [0, 0.2, 0.5, 1],
        "alpha2": [0, 0.2, 0.5, 1],
        "alpha3": [0, 0.2, 0.5, 1],
        "num_maxmin_edges": -1,

        "use_power": [True],
        "use_grumbel": [True],
        "power_beta": [1],
        "sparse_sim_matrix": [True],
        "mean_field_beta": [3],
        "info_gain_lambda": [1],
        "running_avg": True,
        "num_edges_info_gain": [50],
        "U_size": [1],
        "G_size": [1],
        "info_gain_object_mode": ["uniform"],
        "info_gain_pair_mode": ["uniform"],
        "mf_iterations": [50],
    },
    "dataset_options": {
        "dataset": "synthetic",
        "n_samples": 500,
        "n_clusters": 10,
        "class_balance": None
    }
}



start_index = exp_reader.generate_experiments(
    folder="../configs/final_icml2/", 
    options_to_keep=[],
    start_index=start_index,
    **config
)

# %%
config = {
    "general_options": {
        "experiment_name": "final_icml2",
        "num_repeats": 14,
        "n_workers": 14,
        "local": True,
        "verbose": False
    },
    "experiment_options": {
        "seed": 13,
        "num_feedback": [0.01, 0.005],
        "noise_level": [0.4, 0.6],
        "persistent_noise_level": 0.0,
        "save_matrix_data": False,
        "infer_sims": False,
        "predict_sims": False,
        "clustering_alg": "CC",
        "warm_start": [0, 0.02]
    },

    "sim_init_options": {
        "K_init": 10,
        "sim_init": [0.01],
        "sim_init_type": ["custom"]
    },
    "query_strategy_options": {
        "acq_fn": ["entropy", "cluster_incon", "maxexp", "maxmin"],
        "eps": [0.3],
        "beta": [1],
        "tau": [7],
        "alpha": [0, 0.2, 0.5, 1],
        "alpha2": [0, 0.2, 0.5, 1],
        "alpha3": [0, 0.2, 0.5, 1],
        "num_maxmin_edges": -1,

        "use_power": [True],
        "use_grumbel": [True],
        "power_beta": [1],
        "sparse_sim_matrix": [True],
        "mean_field_beta": [3],
        "info_gain_lambda": [1],
        "running_avg": True,
        "num_edges_info_gain": [50],
        "U_size": [1],
        "G_size": [1],
        "info_gain_object_mode": ["uniform"],
        "info_gain_pair_mode": ["uniform"],
        "mf_iterations": [50],
    },
    "dataset_options": {
        "dataset": "synthetic",
        "n_samples": 500,
        "n_clusters": 10,
        "class_balance": None
    }
}

from rac.experiment_data import ExperimentReader
metrics = ["rand", "ami"]
ac = ExperimentReader(metrics=metrics)
data = ac.read_all_data(folder="../experiment_results_local/final_icml2")
#data_filtered = ac.filter_dataframe(data, config2).reset_index()

#data = ac.read_all_data(folder="../experiment_results_local/info_gain_exp_synthetic")
ac.generate_AL_curves(
    data,
    save_location="../plots/final_icml2",
    categorize=["num_feedback", "noise_level", "warm_start", "alpha", "alpha2", "alpha3"],
    compare=["acq_fn"],
    vary=["x"],
    auc=True,
    summary_method="auc_max_ind",
    indices=[], 
    threshold=1,
    err_style="band",
    marker="o",
    markersize=6,
    capsize=6,
    linestyle="solid",
    **config
)
# Out:
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# ...
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:571: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)

# %%
from rac.experiment_data import ExperimentReader
exp_reader = ExperimentReader(["rand"])

#datasets = ["20newsgroups", "cifar10", "mnist", "cardiotocography", "yeast", "ecoli", "forest_type_mapping", "user_knowledge", "synthetic"]
#datasets = ["20newsgroups"]
datasets = {"20newsgroups": 20, "cifar10": 3, "mnist": 3, "cardiotocography": 10, "yeast": 10, "ecoli": 10, "forest_type_mapping": 3, "user_knowledge": 5, "synthetic": 10}
#datasets = ["20newsgroups"]

start_index = 1
#for dataset in datasets:
for dataset, K_init in datasets.items():
    dataset_options =  {
            "dataset": dataset
        }
    if dataset == "20newsgroups":
        warm_start = [0, 0.05]
    elif dataset == "cifar10":
        warm_start = [0, 0.01]
    elif dataset == "mnist":
        warm_start = [0, 0.01]
    elif dataset == "cardiotocography":
        warm_start = [0, 0.02]
    elif dataset == "yeast":
        warm_start = [0, 0.01]
    elif dataset == "ecoli":
        warm_start = [0, 0.02]
    elif dataset == "forest_type_mapping":
        use_grumbel = True
        warm_start = [0, 0.01]
    elif dataset == "user_knowledge":
        warm_start = [0, 0.02]
    elif dataset == "synthetic":
        warm_start = [0, 0.02]
        dataset_options = {
                "dataset": "synthetic",
                "n_samples": 500,
                "n_clusters": 10,
                "class_balance": None
            }
    else:
        print("HUHUH")

    config = {
        "general_options": {
            "experiment_name": "final_icml0",
            "num_repeats": 14,
            "n_workers": 14,
            "local": True,
            "verbose": False
        },
        "experiment_options": {
            "seed": 14,
            "num_feedback": [0.005, 0.01],
            "noise_level": [0.4, 0.6],
            "persistent_noise_level": 0.0,
            "save_matrix_data": False,
            "infer_sims": False,
            "predict_sims": False,
            "clustering_alg": "CC",
            "warm_start": warm_start
        },

        "sim_init_options": {
            "K_init": K_init,
            "sim_init": [0.01],
            "sim_init_type": ["custom"]
        },
        "query_strategy_options": {
            "acq_fn": ["freq", "entropy", "cluster_incon", "maxexp", "maxmin"],
            "eps": 0.3,
            "beta": 1,
            "tau": [7],
            "alpha": [1],
            "num_maxmin_edges": -1,

            "use_power": [True],
            "use_grumbel": True,
            "power_beta": [1],
            "sparse_sim_matrix": [True],
            "mean_field_beta": 3,
            "info_gain_lambda": 1,
            "running_avg": True,
            "num_edges_info_gain": [50],
            "U_size": [1],
            "G_size": [1],
            "info_gain_object_mode": ["uniform"],
            "info_gain_pair_mode": "uniform",
            "mf_iterations": [50],
        },
        "dataset_options": dataset_options
    }


    start_index = exp_reader.generate_experiments(
        folder="../configs/final_icml0/", 
        options_to_keep=[],
        start_index=start_index,
        **config
    )
# Out:
# HUHUH

# %%
from rac.experiment_data import ExperimentReader
exp_reader = ExperimentReader(["rand"])

#datasets = ["20newsgroups", "cifar10", "mnist", "cardiotocography", "yeast", "ecoli", "forest_type_mapping", "user_knowledge", "synthetic"]
#datasets = ["20newsgroups"]
datasets = {"20newsgroups": 20, "cifar10": 3, "mnist": 3, "cardiotocography": 10, "yeast": 10, "ecoli": 10, "forest_type_mapping": 3, "user_knowledge": 5, "synthetic": 10}
#datasets = ["20newsgroups"]

start_index = 1
#for dataset in datasets:
for dataset, K_init in datasets.items():
    dataset_options =  {
            "dataset": dataset
        }
    if dataset == "20newsgroups":
        warm_start = [0, 0.05]
    elif dataset == "cifar10":
        warm_start = [0, 0.01]
    elif dataset == "mnist":
        warm_start = [0, 0.01]
    elif dataset == "cardiotocography":
        warm_start = [0, 0.02]
    elif dataset == "yeast":
        warm_start = [0, 0.01]
    elif dataset == "ecoli":
        warm_start = [0, 0.02]
    elif dataset == "forest_type_mapping":
        use_grumbel = True
        warm_start = [0, 0.01]
    elif dataset == "user_knowledge":
        warm_start = [0, 0.02]
    elif dataset == "synthetic":
        warm_start = [0, 0.02]
        dataset_options = {
                "dataset": "synthetic",
                "n_samples": 500,
                "n_clusters": 10,
                "class_balance": None
            }
    else:
        print("HUHUH")

    config = {
        "general_options": {
            "experiment_name": "final_icml0",
            "num_repeats": 14,
            "n_workers": 14,
            "local": True,
            "verbose": False
        },
        "experiment_options": {
            "seed": 14,
            "num_feedback": [0.005, 0.01],
            "noise_level": [0.4, 0.6],
            "persistent_noise_level": 0.0,
            "save_matrix_data": False,
            "infer_sims": False,
            "predict_sims": False,
            "clustering_alg": "CC",
            "warm_start": warm_start
        },

        "sim_init_options": {
            "K_init": K_init,
            "sim_init": [0.01],
            "sim_init_type": ["custom"]
        },
        "query_strategy_options": {
            "acq_fn": ["freq", "entropy", "cluster_incon", "maxexp", "maxmin"],
            "eps": 0.3,
            "beta": 1,
            "tau": [7],
            "alpha": [1],
            "num_maxmin_edges": -1,

            "use_power": [True],
            "use_grumbel": True,
            "power_beta": [1],
            "sparse_sim_matrix": [True],
            "mean_field_beta": 3,
            "info_gain_lambda": 1,
            "running_avg": True,
            "num_edges_info_gain": [50],
            "U_size": [1],
            "G_size": [1],
            "info_gain_object_mode": ["uniform"],
            "info_gain_pair_mode": "uniform",
            "mf_iterations": [50],
        },
        "dataset_options": dataset_options
    }


    #data = ac.read_all_data(folder="../experiment_results_local/info_gain_exp_synthetic")
    from rac.experiment_data import ExperimentReader
    metrics = ["rand", "ami"]
    ac = ExperimentReader(metrics=metrics)
    if dataset == "synthetic":
        dataset = "synthetic_500_10_None"
    data = ac.read_all_data(folder="../experiment_results_local/final_icml0/" + dataset)
    #data_filtered = ac.filter_dataframe(data, config2).reset_index()

    #data = ac.read_all_data(folder="../experiment_results_local/info_gain_exp/")
    ac.generate_AL_curves_tmlr(
        data,
        save_location="../plots/final_icml0/" + dataset,
        categorize=["num_feedback", "noise_level", "warm_start"],
        compare=["acq_fn"],
        vary=["x"],
        auc=True,
        summary_method="auc_max_ind",
        indices=[], 
        threshold=1,
        err_style="band",
        marker="o",
        markersize=6,
        capsize=6,
        linestyle="solid",
        **config
    )
# Out:
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:931: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:931: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:931: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:931: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:931: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:931: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:931: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:931: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:931: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:931: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:931: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:931: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:931: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:931: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:931: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:931: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:931: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:931: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:931: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:931: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:931: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:931: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:931: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:931: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:931: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:931: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:931: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:931: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:931: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:931: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:931: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:931: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:931: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:931: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:931: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:931: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:931: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:931: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:931: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:931: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:931: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:931: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:931: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:931: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:931: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:931: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:931: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:931: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:931: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:931: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:931: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:931: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:931: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:931: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:931: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:931: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:931: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:931: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:931: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:931: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:931: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:931: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:931: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:931: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:931: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:931: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:931: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:931: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:931: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:931: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:931: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:931: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:931: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:931: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:931: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:931: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:931: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:931: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:931: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:931: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:931: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:931: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:931: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:931: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:931: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:931: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:931: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:931: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:931: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:931: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:931: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:931: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:931: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:931: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:931: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:931: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:931: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:931: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:931: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:931: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:931: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:931: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:931: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:931: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:931: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:931: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:931: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:931: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:931: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:931: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:931: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:931: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:931: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:931: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:931: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:931: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:931: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:931: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:931: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:931: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:931: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:931: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:931: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:931: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:931: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:931: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:931: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:931: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# no data found in folder
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_27148\1927461824.py in <module>
#     100
#     101     #data = ac.read_all_data(folder="../experiment_results_local/info_gain_exp/")
# --> 102     ac.generate_AL_curves_tmlr(
#     103         data,
#     104         save_location="../plots/final_icml0/" + dataset,
#
# c:\github_projects\robust-active-clustering\rac\experiment_data.py in generate_AL_curves_tmlr(self, data, save_location, categorize, compare, vary, auc, summary_method, indices, threshold, err_style, marker, markersize, capsize, linestyle, **config)
#     711                 continue
#     712             col = "mean_" + metric
# --> 713             data[col] = data[metric].apply(lambda x: np.mean(x, axis=0)) # axis 1 since we transpose in read_all_data (i.e., shape is (num_iterations, num_repeats))
#     714             data['array_lengths'] = data[col].apply(lambda x: len(x))
#     715             max_length = data['array_lengths'].max()
#
# TypeError: 'NoneType' object is not subscriptable
