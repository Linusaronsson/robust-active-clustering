# %%
from rac.experiment_data import ExperimentReader
exp_reader = ExperimentReader(["rand"])

#datasets = ["20newsgroups", "cifar10", "mnist", "cardiotocography", "yeast", "ecoli", "forest_type_mapping", "user_knowledge", "synthetic"]
#datasets = ["20newsgroups"]
datasets = {"20newsgroups": 20, "cifar10": 3, "mnist": 3, "cardiotocography": 10, "yeast": 10, "ecoli": 10, "forest_type_mapping": 3, "user_knowledge": 5, "synthetic": 10}
#datasets = ["20newsgroups"]

start_index = 1
#for dataset in datasets:
for dataset, K_init in datasets.items():
    dataset_options =  {
            "dataset": dataset
        }
    if dataset == "20newsgroups":
        use_grumbel = False
        warm_start = [0, 0.05]
        info_gain_pair_mode = "entropy"
        mean_field_beta = 20
        mean_field_lambda = 20
    elif dataset == "cifar10":
        use_grumbel = True
        warm_start = [0, 0.01, 0.02]
        info_gain_pair_mode = "uniform"
        mean_field_beta = 3
        mean_field_lambda = 1
    elif dataset == "mnist":
        use_grumbel = True
        warm_start = [0, 0.01, 0.02]
        info_gain_pair_mode = "uniform"
        mean_field_beta = 3
        mean_field_lambda = 1
    elif dataset == "cardiotocography":
        use_grumbel = False
        warm_start = [0, 0.02]
        info_gain_pair_mode = "entropy"
        mean_field_beta = 20
        mean_field_lambda = 20
    elif dataset == "yeast":
        use_grumbel = True
        warm_start = [0, 0.01, 0.02]
        info_gain_pair_mode = "uniform"
        mean_field_beta = 3
        mean_field_lambda = 1
    elif dataset == "ecoli":
        use_grumbel = True
        warm_start = [0, 0.02, 0.025]
        info_gain_pair_mode = "uniform"
        mean_field_beta = 3
        mean_field_lambda = 1
    elif dataset == "forest_type_mapping":
        use_grumbel = True
        warm_start = [0, 0.01, 0.02]
        info_gain_pair_mode = "uniform"
        mean_field_beta = 3
        mean_field_lambda = 1
    elif dataset == "user_knowledge":
        use_grumbel = True
        warm_start = [0, 0.02, 0.03]
        info_gain_pair_mode = "uniform"
        mean_field_beta = 3
        mean_field_lambda = 1
    elif dataset == "synthetic":
        use_grumbel = True
        warm_start = [0, 0.02]
        info_gain_pair_mode = "uniform"
        mean_field_beta = 3
        mean_field_lambda = 1
        dataset_options = {
                "dataset": "synthetic",
                "n_samples": 500,
                "n_clusters": 10,
                "class_balance": None
            }
    else:
        print("HUHUH")

    config = {
        "general_options": {
            "experiment_name": "final_icml",
            "num_repeats": 14,
            "n_workers": 14,
            "local": True,
            "verbose": False
        },
        "experiment_options": {
            "seed": 14,
            "num_feedback": [0.01],
            "noise_level": [0.2, 0.4, 0.6],
            "persistent_noise_level": 0.0,
            "save_matrix_data": False,
            "infer_sims": False,
            "predict_sims": False,
            "clustering_alg": "CC",
            "warm_start": warm_start
        },

        "sim_init_options": {
            "K_init": K_init,
            "sim_init": [0.01],
            "sim_init_type": ["custom"]
        },
        "query_strategy_options": {
            "acq_fn": ["freq", "entropy", "cluster_incon", "maxexp", "maxmin"],
            "eps": 0.3,
            "beta": 1,
            "tau": [7],
            "alpha": [0.5, 1],
            "num_maxmin_edges": -1,

            "use_power": [True],
            "use_grumbel": use_grumbel,
            "power_beta": [1],
            "sparse_sim_matrix": [True],
            "mean_field_beta": mean_field_beta,
            "info_gain_lambda": mean_field_lambda,
            "running_avg": True,
            "num_edges_info_gain": [50],
            "U_size": [1],
            "G_size": [1],
            "info_gain_object_mode": ["uniform"],
            "info_gain_pair_mode": info_gain_pair_mode,
            "mf_iterations": [50],
        },
        "dataset_options": dataset_options
    }


    start_index = exp_reader.generate_experiments(
        folder="../configs/final_icml/", 
        options_to_keep=[],
        start_index=start_index,
        **config
    )

# %%
from rac.experiment_data import ExperimentReader
exp_reader = ExperimentReader(["rand"])

#datasets = ["20newsgroups", "cifar10", "mnist", "cardiotocography", "yeast", "ecoli", "forest_type_mapping", "user_knowledge", "synthetic"]
#datasets = ["20newsgroups"]
datasets = {"20newsgroups": 20, "cifar10": 3, "mnist": 3, "cardiotocography": 10, "yeast": 10, "ecoli": 10, "forest_type_mapping": 3, "user_knowledge": 5, "synthetic": 10}
#datasets = ["20newsgroups"]

start_index = 1
#for dataset in datasets:
for dataset, K_init in datasets.items():
    dataset_options =  {
            "dataset": dataset
        }
    if dataset == "20newsgroups":
        use_grumbel = False
        warm_start = [0.05]
        info_gain_pair_mode = "entropy"
        mean_field_beta = 20
        mean_field_lambda = 20
    elif dataset == "cifar10":
        use_grumbel = True
        warm_start = [0.01, 0.02]
        info_gain_pair_mode = "uniform"
        mean_field_beta = 3
        mean_field_lambda = 1
    elif dataset == "mnist":
        use_grumbel = True
        warm_start = [0.01, 0.02]
        info_gain_pair_mode = "uniform"
        mean_field_beta = 3
        mean_field_lambda = 1
    elif dataset == "cardiotocography":
        use_grumbel = False
        warm_start = [0.02]
        info_gain_pair_mode = "entropy"
        mean_field_beta = 20
        mean_field_lambda = 20
    elif dataset == "yeast":
        use_grumbel = True
        warm_start = [0.01, 0.02]
        info_gain_pair_mode = "uniform"
        mean_field_beta = 3
        mean_field_lambda = 1
    elif dataset == "ecoli":
        use_grumbel = True
        warm_start = [0.02, 0.025]
        info_gain_pair_mode = "uniform"
        mean_field_beta = 3
        mean_field_lambda = 1
    elif dataset == "forest_type_mapping":
        use_grumbel = True
        warm_start = [0.01, 0.02]
        info_gain_pair_mode = "uniform"
        mean_field_beta = 3
        mean_field_lambda = 1
    elif dataset == "user_knowledge":
        use_grumbel = True
        warm_start = [0.02, 0.03]
        info_gain_pair_mode = "uniform"
        mean_field_beta = 3
        mean_field_lambda = 1
    elif dataset == "synthetic":
        use_grumbel = True
        warm_start = [0.02]
        info_gain_pair_mode = "uniform"
        mean_field_beta = 3
        mean_field_lambda = 1
        dataset_options = {
                "dataset": "synthetic",
                "n_samples": 500,
                "n_clusters": 10,
                "class_balance": None
            }
    else:
        print("HUHUH")

    config = {
        "general_options": {
            "experiment_name": "final_icml",
            "num_repeats": 14,
            "n_workers": 14,
            "local": True,
            "verbose": False
        },
        "experiment_options": {
            "seed": 14,
            "num_feedback": [0.01],
            "noise_level": [0.4, 0.6],
            "persistent_noise_level": 0.0,
            "save_matrix_data": False,
            "infer_sims": False,
            "predict_sims": False,
            "clustering_alg": "CC",
            "warm_start": warm_start
        },

        "sim_init_options": {
            "K_init": K_init,
            "sim_init": [0.01],
            "sim_init_type": ["custom"]
        },
        "query_strategy_options": {
            "acq_fn": ["info_gain_object"],
            "eps": 0.3,
            "beta": 1,
            "tau": [7],
            "alpha": [0.5, 1],
            "num_maxmin_edges": -1,

            "use_power": [True],
            "use_grumbel": use_grumbel,
            "power_beta": [1],
            "sparse_sim_matrix": [True],
            "mean_field_beta": mean_field_beta,
            "info_gain_lambda": mean_field_lambda,
            "running_avg": True,
            "num_edges_info_gain": [50],
            "U_size": [1],
            "G_size": [1],
            "info_gain_object_mode": ["uniform"],
            "info_gain_pair_mode": info_gain_pair_mode,
            "mf_iterations": [50],
        },
        "dataset_options": dataset_options
    }


    start_index = exp_reader.generate_experiments(
        folder="../configs/final_icml_c/", 
        options_to_keep=[],
        start_index=start_index,
        **config
    )

# %%
from rac.experiment_data import ExperimentReader
exp_reader = ExperimentReader(["rand"])

#datasets = ["20newsgroups", "cifar10", "mnist", "cardiotocography", "yeast", "ecoli", "forest_type_mapping", "user_knowledge", "synthetic"]
#datasets = ["20newsgroups"]
datasets = {"20newsgroups": 20, "cifar10": 3, "mnist": 3, "cardiotocography": 10, "yeast": 10, "ecoli": 10, "forest_type_mapping": 3, "user_knowledge": 5, "synthetic": 10}
#datasets = ["20newsgroups"]

start_index = 1
#for dataset in datasets:
for dataset, K_init in datasets.items():
    dataset_options =  {
            "dataset": dataset
        }
    if dataset == "20newsgroups":
        use_grumbel = False
        warm_start = [0.05]
        info_gain_pair_mode = "entropy"
        mean_field_beta = 20
        mean_field_lambda = 20
    elif dataset == "cifar10":
        use_grumbel = True
        warm_start = [0.01, 0.02]
        info_gain_pair_mode = "uniform"
        mean_field_beta = 3
        mean_field_lambda = 1
    elif dataset == "mnist":
        use_grumbel = True
        warm_start = [0.01, 0.02]
        info_gain_pair_mode = "uniform"
        mean_field_beta = 3
        mean_field_lambda = 1
    elif dataset == "cardiotocography":
        use_grumbel = False
        warm_start = [0.02]
        info_gain_pair_mode = "entropy"
        mean_field_beta = 20
        mean_field_lambda = 20
    elif dataset == "yeast":
        use_grumbel = True
        warm_start = [0.01, 0.02]
        info_gain_pair_mode = "uniform"
        mean_field_beta = 3
        mean_field_lambda = 1
    elif dataset == "ecoli":
        use_grumbel = True
        warm_start = [0.02, 0.025]
        info_gain_pair_mode = "uniform"
        mean_field_beta = 3
        mean_field_lambda = 1
    elif dataset == "forest_type_mapping":
        use_grumbel = True
        warm_start = [0.01, 0.02]
        info_gain_pair_mode = "uniform"
        mean_field_beta = 3
        mean_field_lambda = 1
    elif dataset == "user_knowledge":
        use_grumbel = True
        warm_start = [0.02, 0.03]
        info_gain_pair_mode = "uniform"
        mean_field_beta = 3
        mean_field_lambda = 1
    elif dataset == "synthetic":
        use_grumbel = True
        warm_start = [0.02]
        info_gain_pair_mode = "uniform"
        mean_field_beta = 3
        mean_field_lambda = 1
        dataset_options = {
                "dataset": "synthetic",
                "n_samples": 500,
                "n_clusters": 10,
                "class_balance": None
            }
    else:
        print("HUHUH")

    config = {
        "experiment_options": {
            "seed": 14,
            "num_feedback": [0.01],
            "noise_level": [0.4, 0.6],
            "persistent_noise_level": 0.0,
            "save_matrix_data": False,
            "infer_sims": False,
            "predict_sims": False,
            "clustering_alg": "CC",
            "warm_start": warm_start
        },

        "sim_init_options": {
            "K_init": K_init,
            "sim_init": [0.01],
            "sim_init_type": ["zeros", "custom"]
        },
        "query_strategy_options": {
            "acq_fn": ["freq", "entropy", "info_gain_object", "cluster_incon", "maxexp", "maxmin"],
            "eps": 0.3,
            "beta": [1],
            "tau": [7],
            "alpha": [0.5, 1],
            "num_maxmin_edges": -1,

            "use_power": [True],
            "use_grumbel": use_grumbel,
            "power_beta": [1],
            "sparse_sim_matrix": [True],
            "mean_field_beta": mean_field_beta,
            "info_gain_lambda": mean_field_lambda,
            "running_avg": True,
            "num_edges_info_gain": [50],
            "U_size": [1],
            "G_size": [1],
            "info_gain_object_mode": ["uniform"],
            "info_gain_pair_mode": info_gain_pair_mode,
            "mf_iterations": [50],
        },
        "dataset_options": dataset_options
    }


    #data = ac.read_all_data(folder="../experiment_results_local/info_gain_exp_synthetic")
    from rac.experiment_data import ExperimentReader
    metrics = ["rand", "ami"]
    ac = ExperimentReader(metrics=metrics)
    if dataset == "synthetic":
        dataset = "synthetic_500_10_None"
    data = ac.read_all_data(folder="../experiment_results_local/final_icml/" + dataset)
    #data_filtered = ac.filter_dataframe(data, config2).reset_index()

    #data = ac.read_all_data(folder="../experiment_results_local/info_gain_exp/")
    ac.generate_AL_curves_tmlr(
        data,
        save_location="../plots/final_icml_no_legend/",
        categorize=[],
        compare=["acq_fn"],
        vary=["x"],
        auc=True,
        summary_method="auc_max_ind",
        indices=[], 
        threshold=1,
        err_style="band",
        marker="o",
        markersize=6,
        capsize=6,
        linestyle="solid",
        hide_legend=True,
        **config
    )
# Out:
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)

# %%
from rac.experiment_data import ExperimentReader
exp_reader = ExperimentReader(["rand"])

#datasets = ["20newsgroups", "cifar10", "mnist", "cardiotocography", "yeast", "ecoli", "forest_type_mapping", "user_knowledge", "synthetic"]
#datasets = ["20newsgroups"]
datasets = {"20newsgroups": 20, "cifar10": 3, "mnist": 3, "cardiotocography": 10, "yeast": 10, "ecoli": 10, "forest_type_mapping": 3, "user_knowledge": 5, "synthetic": 10}
#datasets = ["20newsgroups"]

start_index = 1
#for dataset in datasets:
for dataset, K_init in datasets.items():
    dataset_options =  {
            "dataset": dataset
        }
    if dataset == "20newsgroups":
        use_grumbel = False
        warm_start = [0.05]
        info_gain_pair_mode = "entropy"
        mean_field_beta = 20
        mean_field_lambda = 20
    elif dataset == "cifar10":
        use_grumbel = True
        warm_start = [0.01, 0.02]
        info_gain_pair_mode = "uniform"
        mean_field_beta = 3
        mean_field_lambda = 1
    elif dataset == "mnist":
        use_grumbel = True
        warm_start = [0.01, 0.02]
        info_gain_pair_mode = "uniform"
        mean_field_beta = 3
        mean_field_lambda = 1
    elif dataset == "cardiotocography":
        use_grumbel = False
        warm_start = [0.02]
        info_gain_pair_mode = "entropy"
        mean_field_beta = 20
        mean_field_lambda = 20
    elif dataset == "yeast":
        use_grumbel = True
        warm_start = [0.01, 0.02]
        info_gain_pair_mode = "uniform"
        mean_field_beta = 3
        mean_field_lambda = 1
    elif dataset == "ecoli":
        use_grumbel = True
        warm_start = [0.02, 0.025]
        info_gain_pair_mode = "uniform"
        mean_field_beta = 3
        mean_field_lambda = 1
    elif dataset == "forest_type_mapping":
        use_grumbel = True
        warm_start = [0.01, 0.02]
        info_gain_pair_mode = "uniform"
        mean_field_beta = 3
        mean_field_lambda = 1
    elif dataset == "user_knowledge":
        use_grumbel = True
        warm_start = [0.02, 0.03]
        info_gain_pair_mode = "uniform"
        mean_field_beta = 3
        mean_field_lambda = 1
    elif dataset == "synthetic":
        use_grumbel = True
        warm_start = [0.02]
        info_gain_pair_mode = "uniform"
        mean_field_beta = 3
        mean_field_lambda = 1
        dataset_options = {
                "dataset": "synthetic",
                "n_samples": 500,
                "n_clusters": 10,
                "class_balance": None
            }
    else:
        print("HUHUH")

    config = {
        "experiment_options": {
            "seed": 14,
            "num_feedback": [0.01],
            "noise_level": [0.4, 0.6],
            "persistent_noise_level": 0.0,
            "save_matrix_data": False,
            "infer_sims": False,
            "predict_sims": False,
            "clustering_alg": "CC",
            "warm_start": warm_start
        },

        "sim_init_options": {
            "K_init": K_init,
            "sim_init": [0.01],
            "sim_init_type": ["zeros", "custom"]
        },
        "query_strategy_options": {
            "acq_fn": ["freq", "entropy", "info_gain_object", "cluster_incon", "maxexp", "maxmin"],
            "eps": 0.3,
            "beta": [1],
            "tau": [7],
            "alpha": [0.5, 1],
            "num_maxmin_edges": -1,

            "use_power": [True],
            "use_grumbel": use_grumbel,
            "power_beta": [1],
            "sparse_sim_matrix": [True],
            "mean_field_beta": mean_field_beta,
            "info_gain_lambda": mean_field_lambda,
            "running_avg": True,
            "num_edges_info_gain": [50],
            "U_size": [1],
            "G_size": [1],
            "info_gain_object_mode": ["uniform"],
            "info_gain_pair_mode": info_gain_pair_mode,
            "mf_iterations": [50],
        },
        "dataset_options": dataset_options
    }


    #data = ac.read_all_data(folder="../experiment_results_local/info_gain_exp_synthetic")
    from rac.experiment_data import ExperimentReader
    metrics = ["rand", "ami"]
    ac = ExperimentReader(metrics=metrics)
    if dataset == "synthetic":
        dataset = "synthetic_500_10_None"
    data = ac.read_all_data(folder="../experiment_results_local/final_icml/" + dataset)
    #data_filtered = ac.filter_dataframe(data, config2).reset_index()

    #data = ac.read_all_data(folder="../experiment_results_local/info_gain_exp/")
    ac.generate_AL_curves_tmlr(
        data,
        save_location="../plots/final_icml/",
        categorize=[],
        compare=["acq_fn"],
        vary=["x"],
        auc=True,
        summary_method="auc_max_ind",
        indices=[], 
        threshold=1,
        err_style="band",
        marker="o",
        markersize=6,
        capsize=6,
        linestyle="solid",
        hide_legend=False,
        **config
    )
# Out:
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)
# c:\github_projects\robust-active-clustering\rac\experiment_data.py:997: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)

# %%
datasets = {"20newsgroups": 20, "cifar10": 3, "mnist": 3, "cardiotocography": 10, "yeast": 10, "ecoli": 10, "forest_type_mapping": 3, "user_knowledge": 5, "synthetic": 10}

# %%
import os
import pickle
hh = 0
for path, subdirs, files in os.walk("../experiment_results_local/info_gain_exp_rw_new"):
    for name in files:
        if name == "completed_experiments.txt":
            continue
        with open(path + "/" + name, 'rb') as handle:
            try:
                exp = pickle.load(handle)
            except EOFError:
                print("EOF error in read data")
                continue
                exp = []
            #print(name)
            if exp[0].acq_fn == "info_gain_object":
                for e in exp:
                    e.beta = 1
                    e.K_init = datasets[e.dataset]
                ds = exp[0].dataset
                if exp[0].dataset == "synthetic":
                    ds = "synthetic_500_10_None"
                print(exp[0].dataset)
                print(name)
                name = name + "MODIFIED"
                with open("../experiment_results_local/final_icml/" + ds + "/" + name, 'wb') as handle:
                    pickle.dump(exp, handle, protocol=pickle.HIGHEST_PROTOCOL)
# Out:
# 20newsgroups
# 5f9f2a9e6b0bec6088fc0370c92c42787509ca9c6160c9138cc80434d16a63ba
# 20newsgroups
# d92492c2edb46bdf39c7fc286ed51ea853c473170f83c1aae7e8a83904136ec9
# cardiotocography
# 0284dd518009efdfa8e3fc89db64c77f4d02bd666de38e9abc7d04e814dc8669
# cardiotocography
# a9ede5cc7ce53ee408b3d301f02d90d6f90ffcbe7edd528fb15b242a1dc50b68
# cifar10
# 25a03bbfdc8c7ca5e434d6ec13b93928d3f560c996bf46a0db164dc5f5ac00d5
# cifar10
# 3a762dc5d503d5a6c193eb7071e0905ab259fb089f38089ce7f3cbccd98fd7fc
# ecoli
# 112866750c3e36d8d1eaab51bc922a16a55c0ad78ba7f9aaa95b14a9a18a2924
# ecoli
# 7052e20f493359ab0b15826d091329f483525616cfbcb5e19403ca47e1c738ee
# forest_type_mapping
# 0beb6f9aebf76cad6939622e71183bb3ccd045cc59e0a1f2fbc9caa05b9623f1
# forest_type_mapping
# 7a6f26b625d57d619b8dd779c6efcb9ea74a83622c70315ea8528e172a3a0d6e
# mnist
# 4e252626ebda292cc10e36dc1dbcfdb227b0418fdcfc2e5122edc54d32569366
# mnist
# cd6dd93e557a7de111b5a43e86507deee297034782e7c26a7928091562b17a78
# synthetic
# 20d7a9880147741b82f08ef8f77bcf0df212432841543f84f76438a08575ec7b
# synthetic
# 406202444445ca6427bca95ba364186449dc56087069e5a4b05f782954eeb0c0
# user_knowledge
# 6ad836be43cd254c649a9b9324af8800ed71875f7041defc2839da5cace89468
# user_knowledge
# c739203e542559abdabb08db8bb09061cdae941fb2b07fca72e5e5c3e7dbd354
# yeast
# 2a2a1daac415d99be7fb8cdfb15246a7ab1a55fe0003e5b7a77e8525550e14ff
# yeast
# 7689bedd485732a56241eeae24b06a29b875766528e47c2540625ee38dabac57

# %%
import os
import pickle
hh = 0
for path, subdirs, files in os.walk("../experiment_results_local/info_gain_exp_rw_new"):
    for name in files:
        if name == "completed_experiments.txt":
            continue
        with open(path + "/" + name, 'rb') as handle:
            try:
                exp = pickle.load(handle)
            except EOFError:
                print("EOF error in read data")
                continue
                exp = []
            #print(name)
            if exp[0].acq_fn == "info_gain_object":
                name = name + "MODIFIED"
                for e in exp:
                    e.alpha = 0.5
                    e.beta = 1
                    e.K_init = datasets[e.dataset]
                if exp[0].dataset == "synthetic":
                    ds = "synthetic_500_10_None"
                else:
                    ds = exp[0].dataset
                name += str(hh)
                hh += 1
                print(name)
                print(ds)
                with open("../experiment_results_local/final_icml/" + ds + "/" + name, 'wb') as handle:
                    pickle.dump(exp, handle, protocol=pickle.HIGHEST_PROTOCOL)
# Out:
# 5f9f2a9e6b0bec6088fc0370c92c42787509ca9c6160c9138cc80434d16a63baMODIFIED0
# 20newsgroups
# d92492c2edb46bdf39c7fc286ed51ea853c473170f83c1aae7e8a83904136ec9MODIFIED1
# 20newsgroups
# 0284dd518009efdfa8e3fc89db64c77f4d02bd666de38e9abc7d04e814dc8669MODIFIED2
# cardiotocography
# a9ede5cc7ce53ee408b3d301f02d90d6f90ffcbe7edd528fb15b242a1dc50b68MODIFIED3
# cardiotocography
# 25a03bbfdc8c7ca5e434d6ec13b93928d3f560c996bf46a0db164dc5f5ac00d5MODIFIED4
# cifar10
# 3a762dc5d503d5a6c193eb7071e0905ab259fb089f38089ce7f3cbccd98fd7fcMODIFIED5
# cifar10
# 112866750c3e36d8d1eaab51bc922a16a55c0ad78ba7f9aaa95b14a9a18a2924MODIFIED6
# ecoli
# 7052e20f493359ab0b15826d091329f483525616cfbcb5e19403ca47e1c738eeMODIFIED7
# ecoli
# 0beb6f9aebf76cad6939622e71183bb3ccd045cc59e0a1f2fbc9caa05b9623f1MODIFIED8
# forest_type_mapping
# 7a6f26b625d57d619b8dd779c6efcb9ea74a83622c70315ea8528e172a3a0d6eMODIFIED9
# forest_type_mapping
# 4e252626ebda292cc10e36dc1dbcfdb227b0418fdcfc2e5122edc54d32569366MODIFIED10
# mnist
# cd6dd93e557a7de111b5a43e86507deee297034782e7c26a7928091562b17a78MODIFIED11
# mnist
# 20d7a9880147741b82f08ef8f77bcf0df212432841543f84f76438a08575ec7bMODIFIED12
# synthetic_500_10_None
# 406202444445ca6427bca95ba364186449dc56087069e5a4b05f782954eeb0c0MODIFIED13
# synthetic_500_10_None
# 6ad836be43cd254c649a9b9324af8800ed71875f7041defc2839da5cace89468MODIFIED14
# user_knowledge
# c739203e542559abdabb08db8bb09061cdae941fb2b07fca72e5e5c3e7dbd354MODIFIED15
# user_knowledge
# 2a2a1daac415d99be7fb8cdfb15246a7ab1a55fe0003e5b7a77e8525550e14ffMODIFIED16
# yeast
# 7689bedd485732a56241eeae24b06a29b875766528e47c2540625ee38dabac57MODIFIED17
# yeast
